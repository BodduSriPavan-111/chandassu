# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# c:\Users\bsnra\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
os.getcwd()
# Out:
# 'c:\\Users\\bsnra\\Desktop\\chandassu\\examples'

# %%
path= 'c:\\Users\\bsnra\\Desktop\\chandassu\\dataset'
os.chdir( path )

# %%
df= pd.DataFrame()
for i in os.listdir():
    if df.shape[0]==0:
        df= pd.read_excel(i)
    else:
        df= pd.concat([df, pd.read_excel(i)])

# %%
df
# Out:
#               type                                             padyam  \
# 0          seesamu  శ్రీమదనంత లక్ష్మీ యుతోరః స్థల- చతురాననాండ పూరి...
# 1      teytageethi  భాను సితభాను నేత్ర సౌభాగ్యగాత్ర-యోగిహృద్గేయ భవ...
# 2          seesamu  వైజయంతీధామ వర్ణిత సుత్రామ- శోభననామ లోకాభిరామ\n...
# 3      teytageethi  దాసులము గామ? నీ పేరు దలఁచుకోమ?-కొసరితిమి ప్రేమ...
# 4          seesamu  మానుషహర్యక్ష మార్తాండ సోమాక్ష- త్రిభువనాధ్యక్ష...
# ..             ...                                                ...
# 104  champakamaala  బసవ నిధానమా! బసవ భవ్యనిధీ! బసవామృతాంబుధీ!\nబసవ...
# 105   vutpalamaala  నా యొడయండ! నా విభుఁడ! నా హృదయేశ్వర! నా మనోరమా!...
# 106   vutpalamaala  నోరికి వచ్చినట్టు నిను నూఱువిధంబులఁ బ్రస్తుతిం...
# 107  champakamaala  \tబసవఁడు ప్రీతిఁ గైకొనియె భక్తిమెయిన్‌ రచియించ...
# 108  champakamaala  అకుటిల లింగ జంగమ సమగ్రదయాకలిత ప్రసాది పా\nలకుర...
#
#        bhedam         satakam
# 0    vruttamu  aandhranaayaka
# 1    vruttamu  aandhranaayaka
# 2    vruttamu  aandhranaayaka
# 3    vruttamu  aandhranaayaka
# 4    vruttamu  aandhranaayaka
# ..        ...             ...
# 104  vruttamu     vrushadhipa
# 105  vruttamu     vrushadhipa
# 106  vruttamu     vrushadhipa
# 107  vruttamu     vrushadhipa
# 108  vruttamu     vrushadhipa
#
# [4884 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4884 entries, 0 to 108
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   type     4884 non-null   object
#  1   padyam   4884 non-null   object
#  2   bhedam   4884 non-null   object
#  3   satakam  4884 non-null   object
# dtypes: object(4)
# memory usage: 190.8+ KB

# %%
df.describe()
# Out:
#               type                                             padyam  \
# count         4884                                               4884
# unique           9                                               4884
# top     aataveladi  శ్రీమదనంత లక్ష్మీ యుతోరః స్థల- చతురాననాండ పూరి...
# freq           995                                                  1
#
#             bhedam satakam
# count         4884    4884
# unique           3      29
# top     vupajaathi  vemana
# freq          2554    1163

# %% [markdown]
# ##### satakam

# %%
satakam= df["satakam"].value_counts()
satakam
# Out:
# satakam
# vemana                    1163
# viswanaatha                232
# aandhranaayaka             212
# venugopaala                210
# laavanya                   200
# narasimha                  200
# madanagopala               200
# kukkuteswara               184
# sarveswara                 144
# taadimallaraajagopaala     130
# sampangimanna              120
# ontimittaraguveera         120
# srikaalahasteeswara        119
# maaruthi                   116
# bhaskara                   110
# vrushadhipa                109
# sumathi                    108
# naarayana                  105
# kumaara                    104
# daasarathi                 103
# bhaktamandaara             101
# devakinandana              101
# bharga                     101
# krishna                    101
# maathru                    100
# kumaarii                   100
# venkateswara               100
# chiravibhava                96
# sundariimani                95
# Name: count, dtype: int64

# %%
plt.figure( figsize= (15, 5) )

plt.barh( range(satakam.shape[0]), satakam.values, color= "cornflowerblue" )
plt.axvline(x=100, color='lime', linestyle='--', label='Non Vupajaathi Satakam')
plt.axvline(x=200, color='green', linestyle='--', label='Vupajaathi Satakam')

plt.yticks( range(satakam.shape[0]), satakam.index )
plt.title("Distribution of no.of Padyams from each Satakam")
plt.legend(
            title= "Satakam Type",
            loc='upper right',
            bbox_to_anchor=(1.2, 1)
           )

plt.show()

# %% [markdown]
# ##### bhedam

# %%
bhedam= df["bhedam"].value_counts()
bhedam
# Out:
# bhedam
# vupajaathi    2554
# vruttamu      1676
# jaathi         654
# Name: count, dtype: int64

# %%
plt.figure( figsize= (15, 5) )
plt.bar( range(bhedam.shape[0]), bhedam.values )
plt.xticks( range(bhedam.shape[0]), bhedam.index  )
plt.show()

# %%
plt.figure( figsize= (15, 5) )
plt.pie( bhedam.values, labels= bhedam.index )
plt.show()

# %% [markdown]
# ##### type

# %%
type= df["type"].value_counts()

# %%
plt.figure( figsize= (15, 5) )
plt.bar( range(type.shape[0]), type.values )
plt.xticks( range(type.shape[0]), type.index  )
plt.show()

# %%
plt.figure( figsize= (15, 5) )
plt.pie( type.values, labels= type.index )
plt.show()
