# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'c:\\Users\\bsnra\\Desktop\\chandassu\\dataset\\lg'

# %%
path= 'c:\\Users\\bsnra\\Desktop\\chandassu\\dataset\\lg'
os.chdir( path )

# %%
df= pd.DataFrame()
for i in os.listdir():
    if df.shape[0]==0:
        df= pd.read_excel(i)
    else:
        df= pd.concat([df, pd.read_excel(i)])

    if "geethamu" in df["type"].value_counts().index:
        print(i)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4651 entries, 0 to 108
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   type     4651 non-null   object
#  1   padyam   4651 non-null   object
#  2   class    4651 non-null   object
#  3   satakam  4651 non-null   object
#  4   lg       4651 non-null   object
# dtypes: object(5)
# memory usage: 218.0+ KB

# %%
df.describe()
# Out:
#               type                                             padyam  \
# count         4652                                               4652
# unique           8                                               4652
# top     aataveladi  శ్రీమదనంత లక్ష్మీ యుతోరః స్థల- చతురాననాండ పూరి...
# freq           995                                                  1
#
#              class satakam                                                 lg
# count         4652    4652                                               4652
# unique           3      29                                               4652
# top     vupajaathi  vemana  [('శ్రీ', 'U'), ('మ', '|'), ('ద', '|'), ('నం',...
# freq          2323    1163                                                  1

# %% [markdown]
# ##### satakam

# %%
satakam= df["satakam"].value_counts()
satakam
# Out:
# satakam
# vemana                    1163
# aandhranaayaka             212
# venugopaala                210
# laavanya                   200
# narasimha                  200
# madanagopala               200
# kukkuteswara               184
# sarveswara                 144
# taadimallaraajagopaala     130
# ontimittaraguveera         120
# sampangimanna              120
# srikaalahasteeswara        119
# maaruthi                   116
# bhaskara                   109
# vrushadhipa                109
# sumathi                    108
# naarayana                  105
# kumaara                    104
# daasarathi                 103
# krishna                    101
# bhaktamandaara             101
# bharga                     101
# devakinandana              101
# maathru                    100
# kumaarii                   100
# venkateswara               100
# chiravibhava                96
# sundariimani                95
# prarthana                    1
# Name: count, dtype: int64

# %%
plt.figure( figsize= (15, 5) )

plt.barh( range(satakam.shape[0]), satakam.values, color= "cornflowerblue" )
plt.axvline(x=100, color='lime', linestyle='--', label='Non Vupajaathi Satakam')
plt.axvline(x=200, color='green', linestyle='--', label='Vupajaathi Satakam')

plt.yticks( range(satakam.shape[0]), satakam.index )
plt.title("Distribution of no.of Padyams from each Satakam")
plt.legend(
            title= "Satakam Type",
            loc='upper right',
            bbox_to_anchor=(1.2, 1)
           )

plt.show()

# %% [markdown]
# ##### bhedam

# %%
bhedam= df["class"].value_counts()
bhedam
# Out:
# class
# vupajaathi    2323
# vruttamu      1665
# jaathi         663
# Name: count, dtype: int64

# %%
plt.figure( figsize= (15, 5) )
plt.bar( range(bhedam.shape[0]), bhedam.values, color= "cornflowerblue" )
plt.xticks( range(bhedam.shape[0]), bhedam.index  )
plt.title("Distribution of no.of Padyams from each Class")
plt.show()

# %%
plt.figure( figsize= (15, 5) )
plt.pie( bhedam.values, labels= bhedam.index )
plt.show()

# %% [markdown]
# ##### type

# %%
type= df["type"].value_counts()
type
# Out:
# type
# aataveladi       995
# kandamu          683
# teytageethi      676
# seesamu          672
# mattebhamu       617
# champakamaala    389
# vutpalamaala     329
# saardulamu       290
# Name: count, dtype: int64

# %%
plt.figure( figsize= (15, 5) )
plt.bar( range(type.shape[0]), type.values, color= "cornflowerblue" )
plt.xticks( range(type.shape[0]), type.index  )
plt.title("Distribution of no.of Padyams from each Type")
plt.show()

# %%
plt.figure( figsize= (15, 5) )
plt.pie( type.values, labels= type.index )
plt.show()
