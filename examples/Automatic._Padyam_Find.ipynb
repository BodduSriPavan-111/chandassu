# %%
1
# Out:
# 1

# %%
pip install chandassu
# Out:
# Collecting chandassu
#   Downloading chandassu-2.0.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading chandassu-2.0.0-py3-none-any.whl (23 kB)
# Installing collected packages: chandassu
# Successfully installed chandassu-2.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install regex
# Out:
# Collecting regex
#   Downloading regex-2026.5.9-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Downloading regex-2026.5.9-cp311-cp311-win_amd64.whl (278 kB)
# Installing collected packages: regex
# Successfully installed regex-2026.5.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from chandassu.telugu.laghuvu_guruvu import LaghuvuGuruvu
from chandassu.telugu.padya_bhedam import check_padyam

data= """తొండము నేక దంతమును తోరపు బొజ్జయు వామ హస్తమున్
మెండుగ మ్రోయు గజ్జెలును మెల్లని చూపులు మందహాసమున్
కొండొక గుజ్జు రూపమున కోరిన విద్యలకెల్ల నొజ్జవై
యుండెడి పార్వతీ తనయ యోయి గణాధిప నీకు మ్రొక్కెదన్"""

# Generate LaghuvuGuruvu Sequence
lg_data= LaghuvuGuruvu(data= data).generate()

score= check_padyam( 
                        lg_data= lg_data ,
                        type= "vutpalamaala",
                        return_micro_score= True, 
                        verbose= False
                    )

print(score)
# Out:
# {'chandassu_score': 1.0, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 1.0, 'yati_sthanam': 1.0, 'n_aksharalu': 1.0, 'prasa': 1.0}}

# %%
all_types= ["kandamu","aataveladi","teytageethi","seesamu","vutpalamaala","champakamaala","saardulamu","mattebhamu"]

# %%
len(all_types)
# Out:
# 8

# %%
padyam= """శ్రీరఘురామ చారుతులసీదళదామ శమక్షమాది శృం
గారగుణాభిరామ త్రిజగన్నుతశౌర్యరమాలలామ దు
ర్వార కబంధరాక్షసవిరామ జగజ్జనకల్మషార్ణవో
త్తారకనామ భద్రగిరి దాశరథీ! కరుణాపయోనిధీ"""

lg_data= LaghuvuGuruvu(data= padyam).generate()         
type_score= []
for i in all_types:
    score= check_padyam(
                        lg_data= lg_data ,
                        type= i,
                        return_micro_score= True, 
                        verbose= False
                    )
    print(i,score)
    type_score.append([score['chandassu_score'],i])
# Out:
# kandamu {'chandassu_score': 0.53125, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.625, 'yati_sthanam': 0.0, 'prasa': 0.5}}
# aataveladi {'chandassu_score': 0.5666666666666667, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.45, 'yati_sthanam': 0.25}}
# teytageethi {'chandassu_score': 0.5333333333333333, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.35, 'yati_sthanam': 0.25}}
# seesamu {'chandassu_score': 0.375, 'micro_score': {'n_paadalu': 0.75, 'gana_kramam': 0.375, 'yati_sthanam': 0.0}}
# vutpalamaala {'chandassu_score': 0.9928571428571429, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.9642857142857143, 'yati_sthanam': 1.0, 'n_aksharalu': 1.0, 'prasa': 1.0}}
# champakamaala {'chandassu_score': 0.5261904761904762, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.17857142857142858, 'yati_sthanam': 0.25, 'n_aksharalu': 0.9523809523809523, 'prasa': 0.25}}
# saardulamu {'chandassu_score': 0.5251879699248121, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.17857142857142858, 'yati_sthanam': 0.25, 'n_aksharalu': 0.9473684210526315, 'prasa': 0.25}}
# mattebhamu {'chandassu_score': 0.6357142857142858, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.17857142857142858, 'yati_sthanam': 0.0, 'n_aksharalu': 1.0, 'prasa': 1.0}}

# %%
type_score
# Out:
# [[0.53125, 'kandamu'],
#  [0.5666666666666667, 'aataveladi'],
#  [0.5333333333333333, 'teytageethi'],
#  [0.375, 'seesamu'],
#  [0.9928571428571429, 'vutpalamaala'],
#  [0.5261904761904762, 'champakamaala'],
#  [0.5251879699248121, 'saardulamu'],
#  [0.6357142857142858, 'mattebhamu']]

# %%
sorted(type_score,key=lambda x:x[0],reverse= True)[0]
# Out:
# [0.9928571428571429, 'vutpalamaala']

# %%
pip uninstall chandassu

# %%
pip show chandassu
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: chandassu

# %%
pip uninstall chandassu
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# import pandas as pd

# from chandassu.telugu.laghuvu_guruvu import LaghuvuGuruvu
from chandassu.telugu.padya_bhedam import find_padyam

# %%
padyam= """శ్రీరఘురామ చారుతులసీదళదామ శమక్షమాది శృం
గారగుణాభిరామ త్రిజగన్నుతశౌర్యరమాలలామ దు
ర్వార కబంధరాక్షసవిరామ జగజ్జనకల్మషార్ణవో
త్తారకనామ భద్రగిరి దాశరథీ! కరుణాపయోనిధీ"""

find_padyam(data= padyam)
# Out:
# [0.9928571428571429, 'vutpalamaala']

# %%
import matplotlib.pyplot as plt

# %%
type_score
# Out:
# [[0.53125, 'kandamu'],
#  [0.5666666666666667, 'aataveladi'],
#  [0.5333333333333333, 'teytageethi'],
#  [0.375, 'seesamu'],
#  [0.9928571428571429, 'vutpalamaala'],
#  [0.5261904761904762, 'champakamaala'],
#  [0.5251879699248121, 'saardulamu'],
#  [0.6357142857142858, 'mattebhamu']]

# %%
scores=  [i[0] for i in type_score]
padyam_type = [i[1] for i in type_score]

# %%
scores
# Out:
# [0.53125,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.375,
#  0.9928571428571429,
#  0.5261904761904762,
#  0.5251879699248121,
#  0.6357142857142858]

# %%
padyam_type
# Out:
# ['kandamu',
#  'aataveladi',
#  'teytageethi',
#  'seesamu',
#  'vutpalamaala',
#  'champakamaala',
#  'saardulamu',
#  'mattebhamu']

# %%
plt.figure(figsize= (13,6))
plt.bar(range(len(scores)),scores,color= "cornflowerblue",width=0.4)
plt.xticks(range(len(scores)),padyam_type)
plt.show()
