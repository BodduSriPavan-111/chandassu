# %%
l=['''చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
కొంచమైన నదియు గొదవుగాదు
విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
విశ్వదాభిరామ! వినురవేమ!''']
for i in l:
    print(i)
# Out:
# చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
# కొంచమైన నదియు గొదవుగాదు
# విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
# విశ్వదాభిరామ! వినురవేమ!

# %%
l=['''చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
కొంచమైన నదియు గొదవుగాదు
విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
విశ్వదాభిరామ! వినురవేమ!''']
newl=[]
for i in l:
    a=i.split()
    newl.append(a)
print(newl)
# Out:
# [['చిత్త', 'శుద్ధి', 'కలిగి', 'చేసిన', 'పుణ్యంబు', 'కొంచమైన', 'నదియు', 'గొదవుగాదు', 'విత్తనంబు', 'మఱ్ఱి', 'వృక్షంబునకు', 'నెంత', 'విశ్వదాభిరామ!', 'వినురవేమ!']]

# %%
a='''చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
కొంచమైన నదియు గొదవుగాదు
విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
విశ్వదాభిరామ! వినురవేమ!'''
b=list(a)
print(b)
# Out:
# ['చ', 'ి', 'త', '్', 'త', ' ', 'శ', 'ు', 'ద', '్', 'ధ', 'ి', ' ', 'క', 'ల', 'ి', 'గ', 'ి', ' ', 'చ', 'ే', 'స', 'ి', 'న', ' ', 'ప', 'ు', 'ణ', '్', 'య', 'ం', 'బ', 'ు', '\n', 'క', 'ొ', 'ం', 'చ', 'మ', 'ై', 'న', ' ', 'న', 'ద', 'ి', 'య', 'ు', ' ', 'గ', 'ొ', 'ద', 'వ', 'ు', 'గ', 'ా', 'ద', 'ు', '\n', 'వ', 'ి', 'త', '్', 'త', 'న', 'ం', 'బ', 'ు', ' ', 'మ', 'ఱ', '్', 'ఱ', 'ి', ' ', 'వ', 'ృ', 'క', '్', 'ష', 'ం', 'బ', 'ు', 'న', 'క', 'ు', ' ', 'న', 'ె', 'ం', 'త', '\n', 'వ', 'ి', 'శ', '్', 'వ', 'ద', 'ా', 'భ', 'ి', 'ర', 'ా', 'మ', '!', ' ', 'వ', 'ి', 'న', 'ు', 'ర', 'వ', 'ే', 'మ', '!']

# %%
import regex as re 
a='''చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
కొంచమైన నదియు గొదవుగాదు
విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
విశ్వదాభిరామ! వినురవేమ!'''
c=re.findall(r"\X",a)
print(c)
def appending(a):
    exp=re.findall(r"\X",a)
    print(exp)
    res=[]
    for i in range(len(exp)-1):
        ith=exp[i]
        jth=exp[i+1]
appending(a)
# Out:
# ['చి', 'త్', 'త', ' ', 'శు', 'ద్', 'ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్', 'యం', 'బు', '\n', 'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n', 'వి', 'త్', 'త', 'నం', 'బు', ' ', 'మ', 'ఱ్', 'ఱి', ' ', 'వృ', 'క్', 'షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n', 'వి', 'శ్', 'వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']
# ['చి', 'త్', 'త', ' ', 'శు', 'ద్', 'ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్', 'యం', 'బు', '\n', 'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n', 'వి', 'త్', 'త', 'నం', 'బు', ' ', 'మ', 'ఱ్', 'ఱి', ' ', 'వృ', 'క్', 'షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n', 'వి', 'శ్', 'వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']

# %%
import regex as re 
a='''చిత్త శుద్ధి కలిగి చేసిన పుణ్యంబు
కొంచమైన నదియు గొదవుగాదు
విత్తనంబు మఱ్ఱి వృక్షంబునకు నెంత
విశ్వదాభిరామ! వినురవేమ!'''
c=re.findall(r"\X",a)
print(c)
# Out:
# ['చి', 'త్', 'త', ' ', 'శు', 'ద్', 'ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్', 'యం', 'బు', '\n', 'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n', 'వి', 'త్', 'త', 'నం', 'బు', ' ', 'మ', 'ఱ్', 'ఱి', ' ', 'వృ', 'క్', 'షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n', 'వి', 'శ్', 'వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']

# %%
l=['చి', 'త్', 'త', ' ', 'శు','ద్', 'ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్', 'యం', 'బు', '\n',
   'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n',
   'వి', 'త్', 'త', 'నం', 'బు', ' ', 'మ', 'ఱ్', 'ఱి', ' ', 'వృ', 'క్', 'షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n',
   'వి', 'శ్', 'వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']
newl=[]
i=0
while(i<len(l)):
    if(i+1 < len(l) and l[i]=='త్' and l[i+1]=='త'):
        newl.append("త్త")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ద్' and l[i+1]=='ధి'):
        newl.append("ద్ధి")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ణ్' and l[i+1]=='యం'):
        newl.append("ణ్యం")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ఱ్' and l[i+1]=='ఱి'):
        newl.append("ఱ్ఱి")
        i=i+2
    elif(i+1 < len(l) and l[i]== 'క్' and l[i+1]=='షం'):
        newl.append("క్షం")
        i=i+2
    elif(i+1 < len(l) and l[i]=='శ్' and l[i+1]=='వ'):
        newl.append("శ్వ")
        i=i+2
    else:
        newl.append(l[i])
        i=i+1
print(newl)
for i in newl:
    splitting=i.split("\n")
    print(splitting)
# Out:
# ['చి', 'త్త', ' ', 'శు', 'ద్ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్యం', 'బు', '\n', 'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n', 'వి', 'త్త', 'నం', 'బు', ' ', 'మ', 'ఱ్ఱి', ' ', 'వృ', 'క్షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n', 'వి', 'శ్వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']
# ['చి']
# ['త్త']
# [' ']
# ['శు']
# ['ద్ధి']
# [' ']
# ['క']
# ['లి']
# ['గి']
# [' ']
# ['చే']
# ['సి']
# ['న']
# [' ']
# ['పు']
# ['ణ్యం']
# ['బు']
# ['', '']
# ['కొం']
# ['చ']
# ['మై']
# ['న']
# [' ']
# ['న']
# ['ది']
# ['యు']
# [' ']
# ['గొ']
# ['ద']
# ['వు']
# ['గా']
# ['దు']
# ['', '']
# ['వి']
# ['త్త']
# ['నం']
# ['బు']
# [' ']
# ['మ']
# ['ఱ్ఱి']
# [' ']
# ['వృ']
# ['క్షం']
# ['బు']
# ['న']
# ['కు']
# [' ']
# ['నెం']
# ['త']
# ['', '']
# ['వి']
# ['శ్వ']
# ['దా']
# ['భి']
# ['రా']
# ['మ']
# ['!']
# [' ']
# ['వి']
# ['ను']
# ['ర']
# ['వే']
# ['మ']
# ['!']

# %%
l=['చి', 'త్', 'త', ' ', 'శు','ద్', 'ధి', ' ', 'క', 'లి', 'గి', ' ', 'చే', 'సి', 'న', ' ', 'పు', 'ణ్', 'యం', 'బు', '\n',
   'కొం', 'చ', 'మై', 'న', ' ', 'న', 'ది', 'యు', ' ', 'గొ', 'ద', 'వు', 'గా', 'దు', '\n',
   'వి', 'త్', 'త', 'నం', 'బు', ' ', 'మ', 'ఱ్', 'ఱి', ' ', 'వృ', 'క్', 'షం', 'బు', 'న', 'కు', ' ', 'నెం', 'త', '\n',
   'వి', 'శ్', 'వ', 'దా', 'భి', 'రా', 'మ', '!', ' ', 'వి', 'ను', 'ర', 'వే', 'మ', '!']
c=1
for i in l:
    if(i=='\n'):
        c=c+1
print("paadaalu in padyam :",c)        
newl=[]
i=0
while(i<len(l)):
    if(i+1 < len(l) and l[i]=='త్' and l[i+1]=='త'):
        newl.append("త్త")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ద్' and l[i+1]=='ధి'):
        newl.append("ద్ధి")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ణ్' and l[i+1]=='యం'):
        newl.append("ణ్యం")
        i=i+2
    elif(i+1 < len(l) and l[i]=='ఱ్' and l[i+1]=='ఱి'):
        newl.append("ఱ్ఱి")
        i=i+2
    elif(i+1 < len(l) and l[i]== 'క్' and l[i+1]=='షం'):
        newl.append("క్షం")
        i=i+2
    elif(i+1 < len(l) and l[i]=='శ్' and l[i+1]=='వ'):
        newl.append("శ్వ")
        i=i+2
    else:
        newl.append(l[i])
        i=i+1
#print(newl)
count=0
for i in newl:
    if(i=="!"):
        pass
    else:
        a=i.isspace()
        if a :
            pass
        else :
            print("aksharam :",i)
            count=count+1
print("aksharaalu in padyam :",count)
# Out:
# paadaalu in padyam : 4
# aksharam : చి
# aksharam : త్త
# aksharam : శు
# aksharam : ద్ధి
# aksharam : క
# aksharam : లి
# aksharam : గి
# aksharam : చే
# aksharam : సి
# aksharam : న
# aksharam : పు
# aksharam : ణ్యం
# aksharam : బు
# aksharam : కొం
# aksharam : చ
# aksharam : మై
# aksharam : న
# aksharam : న
# aksharam : ది
# aksharam : యు
# aksharam : గొ
# aksharam : ద
# aksharam : వు
# aksharam : గా
# aksharam : దు
# aksharam : వి
# aksharam : త్త
# aksharam : నం
# aksharam : బు
# aksharam : మ
# aksharam : ఱ్ఱి
# aksharam : వృ
# aksharam : క్షం
# aksharam : బు
# aksharam : న
# aksharam : కు
# aksharam : నెం
# aksharam : త
# aksharam : వి
# aksharam : శ్వ
# aksharam : దా
# aksharam : భి
# aksharam : రా
# aksharam : మ
# aksharam : వి
# aksharam : ను
# aksharam : ర
# aksharam : వే
# aksharam : మ
# aksharaalu in padyam : 49
