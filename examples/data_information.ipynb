# %%
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Swathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df_daasarathi=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\daasarathi.xlsx")
df_krishna=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\krishna.xlsx")
df_kumaara=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\kumaara.xlsx")
df_kumaarii=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\kumaarii.xlsx")
df_sampangimanna=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\sampangimanna.xlsx")
df_srikaalahasteeswara=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\srikaalahasteeswara.xlsx")
df_sumathi=pd.read_excel(r"C:\Users\Swathi\Desktop\chandassu\dataset\lg\sumathi.xlsx")

# %%
a=pd.concat([df_daasarathi,df_krishna,df_kumaara,df_kumaarii,df_sampangimanna,df_srikaalahasteeswara,df_sumathi])

# %%
a["Tokens"]=a["lg"].apply(word_tokenize)

# %%
a["Tokens"]
# Out:
# 0      [[, (, ', శ్రీ, ', ,, ', U, ', ), ,, (, ', ర, ...
# 1      [[, (, ', రా, ', ,, ', U, ', ), ,, (, ', మ, ',...
# 2      [[, (, ', అ, ', ,, '|, ', ), ,, (, ', గ, ', ,,...
# 3      [[, (, ', రం, ', ,, ', U, ', ), ,, (, ', గ, ',...
# 4      [[, (, ', శ్రీ, ', ,, ', U, ', ), ,, (, ', ద, ...
#                              ...
# 103    [[, (, ', సి, ', ,, '|, ', ), ,, (, ', రి, ', ...
# 104    [[, (, ', మ, ', ,, '|, ', ), ,, (, ', ది, ', ,...
# 105    [[, (, ', పు, ', ,, ', U, ', ), ,, (, ', త్త్ర...
# 106    [[, (, ', వె, ', ,, '|, ', ), ,, (, ', ల, ', ,...
# 107    [[, (, ', వే, ', ,, ', U, ', ), ,, (, ', స, ',...
# Name: Tokens, Length: 755, dtype: object

# %%
a.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   type     755 non-null    object
#  1   padyam   755 non-null    object
#  2   class    755 non-null    object
#  3   satakam  755 non-null    object
#  4   lg       755 non-null    object
#  5   Tokens   755 non-null    object
# dtypes: object(6)
# memory usage: 41.3+ KB

# %%
a.describe()
# Out:
#            type                                             padyam   class  \
# count       755                                                755     755
# unique        5                                                755       2
# top     kandamu  శ్రీరఘురామ చారుతులసీదళదామ శమక్షమాది శృం\nగారగు...  jaathi
# freq        533                                                  1     513
#
#               satakam                                                 lg  \
# count             755                                                755
# unique              7                                                755
# top     sampangimanna  [('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|'), ('రా'...
# freq              120                                                  1
#
#                                                    Tokens
# count                                                 755
# unique                                                755
# ...

# %%
a["Tokens"].describe()
# Out:
# count                                                   755
# unique                                                  755
# top       [[, (, ', శ్రీ, ', ,, ', U, ', ), ,, (, ', ర, ...
# freq                                                      1
# Name: Tokens, dtype: object

# %%
padyam=a["lg"].value_counts()
padyam
# Out:
# lg
# ...
