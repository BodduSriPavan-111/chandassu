# %% [markdown]
# # PadyamPlot
# ### Visualize Metrical Poetry Types
#
# **Author:** Boddu Sri Pavan </br>
# **License:** MIT

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from chandassu.telugu.padyam_config import *
from chandassu.telugu.visualization import padyam_plot

# %%
kandamu= (({'గా': ("U", "U")}, {'స': ("|", "|", "U")}, {'నల': ("|", "|", "|", "|")}),
({'నల': ("|", "|", "|", "|")}, {'భ': ("U", "|", "|")}, {'జ': ("|", "U", "|")}, {'స': ("|", "|", "U")}, {'గా': ("U", "U")}),
({'గా': ("U", "U")}, {'స': ("|", "|", "U")}, {'నల': ("|", "|", "|", "|")}),
({'నల': ("|", "|", "|", "|")}, {'భ': ("U", "|", "|")}, {'జ': ("|", "U", "|")}, {'స': ("|", "|", "U")}, {'గా': ("U", "U")}))

aataveladi= (({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'భ': ("U", "|", "|")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'ర': ("U", "|", "U")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'భ': ("U", "|", "|")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'సల': ("|", "|", "U", "|")}, {'సల': ("|", "|", "U", "|")}))

teytageethi= (({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}))

seesamu= ( ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}),
           ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),

          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}), 
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),

          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}), 
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),

          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}), 
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),
)

vutpalamaala= getattr( Vruttamu, "vutpalamaala" )
champakamaala= getattr( Vruttamu, "champakamaala")
saardulamu= getattr( Vruttamu, "saardulamu")
mattebhamu= getattr( Vruttamu, "mattebhamu" )

# %% [markdown]
# ### 1. Vruttamu

# %%
gana_kramam= vutpalamaala["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                gana_kramam= gana_kramam, 
                yati_sthanam= (4,0), 
                prasa= True, 
                title= "Vutpalamaala"
            )
# Out:
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Vutpalamaala'}, xlabel='Ganam', ylabel='Paadam'>)

# %%
gana_kramam= champakamaala["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                gana_kramam= gana_kramam, 
                yati_sthanam= (4,1), 
                prasa= True, 
                title= "Champakamaala"
            )
# Out:
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Champakamaala'}, xlabel='Ganam', ylabel='Paadam'>)

# %%
gana_kramam= saardulamu["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                gana_kramam= gana_kramam, 
                yati_sthanam= (5,0), 
                prasa= True, 
                title= "Saardulamu" 
            )
# Out:
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Saardulamu'}, xlabel='Ganam', ylabel='Paadam'>)

# %%
gana_kramam= mattebhamu["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                gana_kramam= gana_kramam, 
                yati_sthanam= (5,1), 
                prasa= True, 
                title= "Mattebhamu" 
            )
# Out:
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Mattebhamu'}, xlabel='Ganam', ylabel='Paadam'>)

# %% [markdown]
# ### 2. Jaathi

# %%
gana_kramam= kandamu
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, 
            yati_sthanam= (4,0), 
            yati_paadaalu= (2,4), 
            prasa= True,
            only_generic_yati= True,
            title= "Kandamu" )
# Out:
# [('U', 'U'), ('|', '|', 'U'), ('|', '|', '|', '|')]
# [('|', '|', '|', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U')]
# [('U', 'U'), ('|', '|', 'U'), ('|', '|', '|', '|')]
# [('|', '|', '|', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Kandamu'}, xlabel='Ganam', ylabel='Paadam'>)

# %% [markdown]
# ### 3. Vupajaathi

# %%
gana_kramam= aataveladi
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, 
            yati_sthanam= (4,0), 
            yati_paadaalu= (1,2,3,4), 
            prasa= False,
            only_generic_yati= False,
            title= "Aataveladi" )
# Out:
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', '|'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', 'U'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', '|'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('|', '|', 'U', '|'), ('|', '|', 'U', '|')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Aataveladi'}, xlabel='Ganam', ylabel='Paadam'>)

# %%
gana_kramam= teytageethi
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                gana_kramam= gana_kramam, 
                yati_sthanam= (4,0), 
                prasa= False, 
                only_generic_yati= False,
                title= "Teytageethi" )
# Out:
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Teytageethi'}, xlabel='Ganam', ylabel='Paadam'>)

# %%
gana_kramam= seesamu
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( 
                figsize= (3,10),
                gana_kramam= gana_kramam, 
                yati_sthanam= (3,0), 
                yati_paadaalu= (1,2,3,4,5,6,7,8),
                prasa= False, 
                title= "Seesamu",
                only_generic_yati= False
            )
# Out:
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# (<Figure size 300x1000 with 1 Axes>,
#  <Axes: title={'center': 'PadyamPlot: Seesamu'}, xlabel='Ganam', ylabel='Paadam'>)

# %% [markdown]
# ### END
# ---
