# %%
ganamulu_telugu= {
            'గ': ("U",),
            'ల': ("|",),
            'లా': ("|", "|"),
            'వ': ("|", "U"),
            'హ': ("U", "|"),
            'గా': ("U", "U"),
            'న': ("|", "|", "|"),
            'స': ("|", "|", "U"),
            'జ': ("|", "U", "|"),
            'య': ("|", "U", "U"),
            'భ': ("U", "|", "|"),
            'ర': ("U", "|", "U"),
            'త': ("U", "U", "|"),
            'మ': ("U", "U", "U"),
            'నల': ("|", "|", "|", "|"),
            'నగ': ("|", "|", "|", "U"),
            'సల': ("|", "|", "U", "|")
}
ganamulu_english= {
            "GA": ("U",),
            'LA': ("|",),
            'LAA': ("|", "|"),
            'VA': ("|", "U"),
            'HA': ("U", "|"),
            'GAA': ("U", "U"),
            'NA': ("|", "|", "|"),
            'SA': ("|", "|", "U"),
            'JA': ("|", "U", "|"),
            'YA': ("|", "U", "U"),
            'BHA': ("U", "|", "|"),
            'RA': ("U", "|", "U"),
            'THA': ("U", "U", "|"),
            'MA': ("U", "U", "U"),
            'NALA': ("|", "|", "|", "|"),
            'NAGA': ("|", "|", "|", "U"),
            'SALA': ("|", "|", "U", "|")
}

# %%
# ganamulu= {
#             'గ': ("U",),                  [1]         1_1     ---> 2
#             'ల': ("|",),                 [0]          1_0    ----> 1
#             'లా': ("|", "|"),            [0,0]         2_0   ----> 2
#             'వ': ("|", "U"),              [0,1]       2_1   ----> 3
#             'హ': ("U", "|"),              [1,0]       2_2  -----> 4
#             'గా': ("U", "U"),              [1,1]       2_3  ------> 5
#             'న': ("|", "|", "|"),         [0,0,0]     3_0   ------> 3
#             'స': ("|", "|", "U"),         [0,0,1]     3_1  -------> 4
#             'జ': ("|", "U", "|"),         [0,1,0]     3_2
#             'య': ("|", "U", "U"),        [0,1,1]      3_3
#             'భ': ("U", "|", "|"),         [1,0,0]     3_4
#             'ర': ("U", "|", "U"),         [1,0,1]     3_5
#             'త': ("U", "U", "|"),         [1,1,0]     3_6
#             'మ': ("U", "U", "U"),         [1,1,1]     3_7
#             'నల': ("|", "|", "|", "|"),   [0,0,0,0]   4_0
#             'నగ': ("|", "|", "|", "U"),    [0,0,0,1]  4_1
#             'సల': ("|", "|", "U", "|")    [0,0,1,0]   4_2
# }

Add more 4 akshara ganalu into 4 leven

# %%
# 1_n ---> 10, 11
# 2_n ---> 20, 21, 22, 23, 
# 3_n ---> 30, 31, 32, 33, 34, 35, 36, 37

# %%
# 'భ': ("U", "|", "|"),   ---> 3_4
# 'ర': ("U", "|", "U"),   ---> 3_5
# 'న': ("|", "|", "|"),  ---> 3_0
# 'భ': ("U", "|", "|"),  ---> 3_4
# 'భ': ("U", "|", "|"),  ---> 3_4
# 'ర': ("U", "|", "U"),  ---> 3_5
# 'వ': ("|", "U"),       ---> 2_1

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from chandassu.telugu.padyam_config import *
from chandassu.telugu.visualization import padyam_plot

# %%
vutpalamaala= getattr( Vruttamu, "vutpalamaala" )
champakamaala= getattr( Vruttamu, "champakamaala")
saardulamu= getattr( Vruttamu, "saardulamu")
mattebhamu= getattr( Vruttamu, "mattebhamu" )

aataveladi= (({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'భ': ("U", "|", "|")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'ర': ("U", "|", "U")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'భ': ("U", "|", "|")}, {'సల': ("|", "|", "U", "|")}),
({'హ': ("U", "|")}, {'న': ("|", "|", "|")}, {'హ': ("U", "|")}, {'సల': ("|", "|", "U", "|")}, {'సల': ("|", "|", "U", "|")}))

teytageethi= (({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}),
({'హ': ("U", "|")}, {'నల': ("|", "|", "|", "|")}, {'నల': ("|", "|", "|", "|")}, {'న': ("|", "|", "|")}, {'న': ("|", "|", "|")}))

seesamu= ( ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),
          ({'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'భ': ("U", "|", "|")}, {'హ': ("U", "|")}, {'హ': ("U", "|")}),
)

# %%
gana_kramam= aataveladi
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (4,0), prasa= False )
# Out:
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', '|'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', 'U'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('U', '|', '|'), ('|', '|', 'U', '|')]
# [('U', '|'), ('|', '|', '|'), ('U', '|'), ('|', '|', 'U', '|'), ('|', '|', 'U', '|')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= teytageethi
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (4,0), prasa= False )
# Out:
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# [('U', '|'), ('|', '|', '|', '|'), ('|', '|', '|', '|'), ('|', '|', '|'), ('|', '|', '|')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= seesamu
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (3,0), prasa= False )
# Out:
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# [('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|'), ('U', '|')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= vutpalamaala["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (4,0), prasa= True )
# Out:
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# [('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', '|', '|'), ('U', '|', '|'), ('U', '|', 'U'), ('|', 'U')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= champakamaala["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (4,1), prasa= True )
# Out:
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# [('|', '|', '|'), ('|', 'U', '|'), ('U', '|', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('|', 'U', '|'), ('U', '|', 'U')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= saardulamu["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (5,0), prasa= True )
# Out:
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# [('U', 'U', 'U'), ('|', '|', 'U'), ('|', 'U', '|'), ('|', '|', 'U'), ('U', 'U', '|'), ('U', 'U', '|'), ('U',)]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
gana_kramam= mattebhamu["gana_kramam"]
for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    print(sequence)

padyam_plot( gana_kramam= gana_kramam, yati_sthanam= (5,1), prasa= True )
# Out:
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# [('|', '|', 'U'), ('U', '|', '|'), ('U', '|', 'U'), ('|', '|', '|'), ('U', 'U', 'U'), ('|', 'U', 'U'), ('|', 'U')]
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from chandassu.telugu.laghuvu_guruvu import LaghuvuGuruvu
from chandassu.telugu.ganam import *
from chandassu.telugu.padyam_config import *
from chandassu.telugu.ganam import *

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import Patch

# %%
ganamulu_telugu= {
            'గ': ("U",),
            'ల': ("|",),
            'లా': ("|", "|"),
            'వ': ("|", "U"),
            'హ': ("U", "|"),
            'గా': ("U", "U"),
            'న': ("|", "|", "|"),
            'స': ("|", "|", "U"),
            'జ': ("|", "U", "|"),
            'య': ("|", "U", "U"),
            'భ': ("U", "|", "|"),
            'ర': ("U", "|", "U"),
            'త': ("U", "U", "|"),
            'మ': ("U", "U", "U"),
            'నల': ("|", "|", "|", "|"),
            'నగ': ("|", "|", "|", "U"),
            'సల': ("|", "|", "U", "|")
}

figsize= (6,6)
 #na, ja, bha, ja, ja, ja, ra
yati_sthanam= 11
prasa= True
# sequence= bha, ra, na, bha, bha, ra, va

# %%
( surya_ganam, surya_ganam, surya_ganam, indra_ganam, indra_ganam )
# Out:
# (({'హ': ('U', '|')},
#   {'న': ('|', '|', '|')},
#   {'హ': ('U', '|')},
#   {'భ': ('U', '|', '|')},
#   {'సల': ('|', '|', 'U', '|')}),)

# %%
include_indra_surya= False

# %%
fig, ax = plt.subplots( figsize= figsize )

patches= []

gana_kramam= mattebhamu["gana_kramam"]

# Find maximum length of AksharamTokens for each paadam
max_each_paadam= [ max( [ len(list(i.values())[0]) for i in gana_kramam[j] ] )    for j in range(len(gana_kramam)) ]

for k in range(len(gana_kramam)):

    each_paadam= gana_kramam[k]

    sequence= [ list(i.values())[0] for i in each_paadam]
    # print( sequence )

    count= 1

    for i in range(len(sequence)):

        each_ganam= sequence[i]

        linewidth= 1
        linestyle= "-"

        if include_indra_surya:

            if each_ganam in r_surya_ganam:
                linewidth= 3

            if each_ganam in r_indra_ganam:
                linestyle= "--"

        for j in range(len(each_ganam)):

            lg= each_ganam[j]
            
            color= "palegreen" if lg == 'U' else "white"

            if count== yati_sthanam:
                edge_color= "darkorange"

            # j is the vertical shift for each Aksharam Token within each paadam
            # len(gana_kramam) - k is the shift for each paadam

            temp= Rectangle( 
                                (i, sum(max_each_paadam) + len(gana_kramam) -1 -  sum(max_each_paadam[:(k+1)]) - k +j ),   
                                width= 1, 
                                height= 1, 
                                facecolor=color,
                                edgecolor= "black",
                                linewidth= linewidth,
                                linestyle= linestyle,
                                hatch= "---" if count in [1, yati_sthanam] else "|||" if (count==2 and prasa== True) else ""
                            )

            patches.append( temp )

            count+= 1

            

            # print( each_lg)
            
        # print( each_ganam )
    

for each_patch in patches:
    ax.add_patch( each_patch )

# plt.xlim([0, 8])
# plt.ylim([0, 15])

ax.relim()
ax.autoscale_view()

# %%
legend_elements = [
                    Patch( facecolor='white', edgecolor= "black", linewidth= 0.5, label='Laghuvu-|'),
                    Patch(facecolor='palegreen', edgecolor= "black", linewidth= 0.5, label='Guruvu-U'),

                    Patch(facecolor='white', edgecolor= "black", linewidth= 0.5, hatch= "|||", label='Prasa (Laghuvu)'),
                    Patch(facecolor='palegreen', edgecolor= "black", linewidth= 0.5, hatch= "|||", label='Prasa (Guruvu)'),

                    Patch(facecolor='white', edgecolor= "black", linewidth= 0.5, hatch= "---", label='Yati (Laghuvu)'),
                    Patch(facecolor='palegreen', edgecolor= "black", linewidth= 0.5, hatch= "---", label='Yati (Guruvu)'),

                    Patch(facecolor='palegreen', edgecolor= "black", linewidth= 1.5, label='Surya Ganam (Guruvu)'),
                    Patch(facecolor='white', edgecolor= "black", linewidth= 1.5, label='Surya Ganam (Laghuvu)')
                ]

# 2. Apply it to your axes
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='upper left')
plt.show()

# %%
0   3   12-15       2*n-1 + 2

1   3   8-11

2   3   4-7

3   3    0-3
# Out:
# [<matplotlib.patches.Rectangle at 0x253fce7e790>,
#  <matplotlib.patches.Rectangle at 0x253ff3f1fd0>,
#  <matplotlib.patches.Rectangle at 0x253fcea7750>]

# %%
k=3
sum(max_each_paadam) + len(gana_kramam) -1 -  sum(max_each_paadam[:(k+1)]) - k
# Out:
# 0

# %%
sum(max_each_paadam) + len(gana_kramam) - 1
# Out:
# 15

# %%
patches= [] 


# for i in range
temp= Rectangle( (0,10),
           width= 3, 
           height= 3, facecolor= "green"
           )

patches.append( temp )
patches.append( temp )
patches.append( temp )

fig, ax = plt.subplots( figsize= (10,5))

for each_patch in patches:
    ax.add_patch( each_patch )

# plt.xlim([0, 40])
# plt.ylim([0,50])

ax.relim()
ax.autoscale_view() 

plt.show()
