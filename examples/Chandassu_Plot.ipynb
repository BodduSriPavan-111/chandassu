# %%
ganamulu= {
            'గ': ("U",),
            'ల': ("|",),
            'లా': ("|", "|"),
            'వ': ("|", "U"),
            'హ': ("U", "|"),
            'గా': ("U", "U"),
            'న': ("|", "|", "|"),
            'స': ("|", "|", "U"),
            'జ': ("|", "U", "|"),
            'య': ("|", "U", "U"),
            'భ': ("U", "|", "|"),
            'ర': ("U", "|", "U"),
            'త': ("U", "U", "|"),
            'మ': ("U", "U", "U"),
            'నల': ("|", "|", "|", "|"),
            'నగ': ("|", "|", "|", "U"),
            'సల': ("|", "|", "U", "|")
}

# %%
# ganamulu= {
#             'గ': ("U",),                  [1]         1_1     ---> 2
#             'ల': ("|",),                 [0]          1_0    ----> 1
#             'లా': ("|", "|"),            [0,0]         2_0   ----> 2
#             'వ': ("|", "U"),              [0,1]       2_1   ----> 3
#             'హ': ("U", "|"),              [1,0]       2_2  -----> 4
#             'గా': ("U", "U"),              [1,1]       2_3  ------> 5
#             'న': ("|", "|", "|"),         [0,0,0]     3_0   ------> 3
#             'స': ("|", "|", "U"),         [0,0,1]     3_1  -------> 4
#             'జ': ("|", "U", "|"),         [0,1,0]     3_2
#             'య': ("|", "U", "U"),        [0,1,1]      3_3
#             'భ': ("U", "|", "|"),         [1,0,0]     3_4
#             'ర': ("U", "|", "U"),         [1,0,1]     3_5
#             'త': ("U", "U", "|"),         [1,1,0]     3_6
#             'మ': ("U", "U", "U"),         [1,1,1]     3_7
#             'నల': ("|", "|", "|", "|"),   [0,0,0,0]   4_0
#             'నగ': ("|", "|", "|", "U"),    [0,0,0,1]  4_1
#             'సల': ("|", "|", "U", "|")    [0,0,1,0]   4_2
# }

Add more 4 akshara ganalu into 4 leven

# %%
# 1_n ---> 10, 11
# 2_n ---> 20, 21, 22, 23, 
# 3_n ---> 30, 31, 32, 33, 34, 35, 36, 37

# %%
# 'భ': ("U", "|", "|"),   ---> 3_4
# 'ర': ("U", "|", "U"),   ---> 3_5
# 'న': ("|", "|", "|"),  ---> 3_0
# 'భ': ("U", "|", "|"),  ---> 3_4
# 'భ': ("U", "|", "|"),  ---> 3_4
# 'ర': ("U", "|", "U"),  ---> 3_5
# 'వ': ("|", "U"),       ---> 2_1
