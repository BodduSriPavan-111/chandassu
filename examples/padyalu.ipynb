# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from chandassu.padyam_config import Vruttamu

import matplotlib.pyplot as plt

# %%
d= {        
            'లా': ("|", "|"),
            'వ': ("|", "U"),
            'హ': ("U", "|"),
            'గా': ("U", "U"),
            'న': ("|", "|", "|"),
            'స': ("|", "|", "U"),
            'జ': ("|", "U", "|"),
            'య': ("|", "U", "U"),
            'భ': ("U", "|", "|"),
            'ర': ("U", "|", "U"),
            'త': ("U", "U", "|"),
            'మ': ("U", "U", "U"),
    }

# %%
Vruttamu.champakamala["gana_kramam"]
# Out:
# ('న', 'జ', 'భ', 'జ', 'జ', 'జ', 'ర')

# %%
plt.plot( range(7), [d[i] for i in Vruttamu.champakamala["gana_kramam"]], label= "Champakamala")
# plt.plot( range(7), [d[i] for i in Vruttamu.vutpalamala["gana_kramam"]], label= "Vutpalamala")
# plt.plot( range(7), [d[i] for i in Vruttamu.mattebham["gana_kramam"]], label= "Mattebham")
plt.plot( range(6), [d[i] for i in Vruttamu.mattakokila["gana_kramam"]], label= "Matta Kokila")
# plt.plot( range(7), [d[i] for i in Vruttamu.sardulam["gana_kramam"]], label= "Sarduulam")

plt.legend()

# %%
d= {"padyam": """తొండము నేకదంతమును తోరపు బొజ్జయు వామహస్తమున్‌
మెండుగ మ్రోయు గజ్జెలును మెల్లని చూపుల మందహాసమున్‌.
కొండొక గుజ్జురూపమున కోరిన విద్యలకెల్ల నొజ్జయై
యుండెడి పార్వతీ తనయ ఓయి గణాధిపా నీకు మ్రొక్కెదన్‌.""",
"bhedam": "VRUTTAMU",
"type": "CHAMPAKAMALA"}

# %%
import json

# %%
with open("a.json", "w") as file:
    json.dump( d, file )

# %%
with open("a.json", "r") as file:
    data= json.load( file )

# %%
data
# Out:
# {'padyam': 'తొండము నేకదంతమును తోరపు బొజ్జయు వామహస్తమున్\u200c\nమెండుగ మ్రోయు గజ్జెలును మెల్లని చూపుల మందహాసమున్\u200c.\nకొండొక గుజ్జురూపమున కోరిన విద్యలకెల్ల నొజ్జయై\nయుండెడి పార్వతీ తనయ ఓయి గణాధిపా నీకు మ్రొక్కెదన్\u200c.',
#  'bhedam': 'VRUTTAMU',
#  'type': 'CHAMPAKAMALA'}

# %%
import matplotlib.pyplot as plt
a={"|":0,"U":1}
plt.plot(a["|"],a["U"],"o");

# %% [markdown]
# # vruttamu

# %% [markdown]
# ## case-| : "|":0,"U":1

# %%
# vutpalamala
#'భ', 'ర', 'న', 'భ', 'భ', 'ర', 'వ'
#("U", "|", "|"): 'భ',
("U", "|", "U"): 'ర',
("|", "|", "|"): 'న',
    ("|", "U"): 'వ',

# %%
a={"U||":100, "U|U":101, "|||":0, "U||":100, "U||":100 ,"U|U":101, "|U":1}
for val in a.values():
    print(val)
# Out:
# 100
# 101
# 0
# 1

# %%
A="100"
print(int(A,2))
# Out:
# 4

# %%
a={"U||":100, "U|U":101, "|||":0, "U||":100, "U||":100 ,"U|U":101, "|U":1}
for val in a.values():
    decimal=int(str(val),2)
    print(decimal)
# Out:
# 4
# 5
# 0
# 1

# %%
b=["U||","U|U","|||","U||","U||","U|U","|U"]
c=[100,101,0,100,100,101,1]
for i in c:
    decimal_val=int(str(i),2)
    print(decimal_val)
# Out:
# 4
# 5
# 0
# 4
# 4
# 5
# 1

# %%
b=["U||","U|U","|||","U||","U||","U|U","|U"]
c=[100,101,0,100,100,101,1]
decimal_val=[]
for i in c:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(b,decimal_val)
plt.show()
# Out:
# [4, 5, 0, 4, 4, 5, 1]

# %%
# champakamala
#('న', 'జ', 'భ', 'జ', 'జ', 'జ', 'ర')
ganam=["|||","|U|","U||","|U|","|U|","|U|","U|U"]
ganam_binary=[0,10,100,10,10,10,101]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [0, 2, 4, 2, 2, 2, 5]

# %%
# sardulam
#('మ', 'స', 'జ', 'స', 'త', 'త', 'గ')
ganam=["UUU","||U","|U|","||U","UU|","UU|","U"]
ganam_binary=[111,1,10,1,110,110,1]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [7, 1, 2, 1, 6, 6, 1]

# %%
#mattebam
#('స', 'భ', 'ర', 'న', 'మ', 'య', 'వ')
ganam=["||U","U||","U|U","|||","UUU","|U"]
ganam_binary=[1,100,101,0,111,1]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [1, 4, 5, 0, 7, 1]

# %%
# mattakokila
#('ర', 'స', 'జ', 'జ', 'భ', 'ర')
ganam=["U|U","||U","|U|","|U|","U||","U|U"]
ganam_binary=[101,1,10,10,100,101]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [5, 1, 2, 2, 4, 5]

# %% [markdown]
# ## case-|| : "|":1,"U":0

# %%
# vutpalamala
b=["U||","U|U","|||","U||","U||","U|U","|U"]
c=[11,10,111,11,11,10,10]
decimal_val=[]
for i in c:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(b,decimal_val)
plt.show()
# Out:
# [3, 2, 7, 3, 3, 2, 2]

# %%
# champakamala
ganam=["|||","|U|","U||","|U|","|U|","|U|","U|U"]
ganam_binary=[111,101,11,101,101,101,10]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [7, 5, 3, 5, 5, 5, 2]

# %%
# sardulam
ganam=["UUU","||U","|U|","||U","UU|","UU|","U"]
ganam_binary=[0,110,101,110,1,1,0]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [0, 6, 5, 6, 1, 1, 0]

# %%
#mattebam
ganam=["||U","U||","U|U","|||","UUU","|U"]
ganam_binary=[110,11,10,111,0,10]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [6, 3, 2, 7, 0, 2]

# %%
# mattakokila
ganam=["U|U","||U","|U|","|U|","U||","U|U"]
ganam_binary=[10,110,101,101,11,10]
decimal_val=[]
for i in ganam_binary:
    decimal=int(str(i),2)
    decimal_val.append(decimal)
print(decimal_val)
plt.plot(ganam,decimal_val)
plt.show()
# Out:
# [2, 6, 5, 5, 3, 2]
