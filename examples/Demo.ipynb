# %% [markdown]
# # Quick Start

# %% [markdown]
# ### Installation

# %%
! pip install chandassu
# Out:
# Collecting chandassu
#   Downloading chandassu-1.1.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\bsnra\anaconda3\lib\site-packages (from chandassu) (1.26.4)
# Downloading chandassu-1.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: chandassu
# Successfully installed chandassu-1.1.0
# WARNING: Ignoring invalid distribution ~illow (C:\Users\bsnra\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\bsnra\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\bsnra\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\bsnra\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\bsnra\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import

# %%
from chandassu.telugu.laghuvu_guruvu import LaghuvuGuruvu
from chandassu.telugu.padya_bhedam import check_padyam

# %% [markdown]
# Toṇḍamu nēka dantamunu tōrapu bojjayu vāma hastamun </br>
# meṇḍuga mrōyu gajjelunu mellani cūpulu mandahāsamun </br>
# koṇḍoka gujju rūpamuna kōrina vidyalakella nojjavai </br>
# yuṇḍeḍi pārvatī tanaya yōyi gaṇādhipa nīku mrokkedan </br>

# %%
data= """తొండము నేక దంతమును తోరపు బొజ్జయు వామ హస్తమున్
మెండుగ మ్రోయు గజ్జెలును మెల్లని చూపులు మందహాసమున్
కొండొక గుజ్జు రూపమున కోరిన విద్యలకెల్ల నొజ్జవై
యుండెడి పార్వతీ తనయ యోయి గణాధిప నీకు మ్రొక్కెదన్"""

# %%
lg= LaghuvuGuruvu( data= data )

# %% [markdown]
# ### Aksharam Tokenization (Character-level Prosody aware tokenization)

# %%
import regex as re
print( re.findall(r"\X", data) )
# Out:
# ['తొం', 'డ', 'ము', ' ', 'నే', 'క', ' ', 'దం', 'త', 'ము', 'ను', ' ', 'తో', 'ర', 'పు', ' ', 'బొ', 'జ్', 'జ', 'యు', ' ', 'వా', 'మ', ' ', 'హ', 'స్', 'త', 'ము', 'న్', '\n', 'మెం', 'డు', 'గ', ' ', 'మ్', 'రో', 'యు', ' ', 'గ', 'జ్', 'జె', 'లు', 'ను', ' ', 'మె', 'ల్', 'ల', 'ని', ' ', 'చూ', 'పు', 'లు', ' ', 'మం', 'ద', 'హా', 'స', 'ము', 'న్', '\n', 'కొం', 'డొ', 'క', ' ', 'గు', 'జ్', 'జు', ' ', 'రూ', 'ప', 'ము', 'న', ' ', 'కో', 'రి', 'న', ' ', 'వి', 'ద్', 'య', 'ల', 'కె', 'ల్', 'ల', ' ', 'నొ', 'జ్', 'జ', 'వై', '\n', 'యుం', 'డె', 'డి', ' ', 'పా', 'ర్', 'వ', 'తీ', ' ', 'త', 'న', 'య', ' ', 'యో', 'యి', ' ', 'గ', 'ణా', 'ధి', 'ప', ' ', 'నీ', 'కు', ' ', 'మ్', 'రొ', 'క్', 'కె', 'ద', 'న్']

# %%
tokens= lg.tokenize()
print( tokens )
# Out:
# ['తొం', 'డ', 'ము', 'నే', 'క', 'దం', 'త', 'ము', 'ను', 'తో', 'ర', 'పు', 'బొ', 'జ్జ', 'యు', 'వా', 'మ', 'హ', 'స్త', 'మున్', 'మెం', 'డు', 'గ', 'మ్రో', 'యు', 'గ', 'జ్జె', 'లు', 'ను', 'మె', 'ల్ల', 'ని', 'చూ', 'పు', 'లు', 'మం', 'ద', 'హా', 'స', 'మున్', 'కొం', 'డొ', 'క', 'గు', 'జ్జు', 'రూ', 'ప', 'ము', 'న', 'కో', 'రి', 'న', 'వి', 'ద్య', 'ల', 'కె', 'ల్ల', 'నొ', 'జ్జ', 'వై', 'యుం', 'డె', 'డి', 'పా', 'ర్వ', 'తీ', 'త', 'న', 'య', 'యో', 'యి', 'గ', 'ణా', 'ధి', 'ప', 'నీ', 'కు', 'మ్రొ', 'క్కె', 'దన్']

# %% [markdown]
# ### Syllabic Weight Classification
# #### 1. Laghuvu: Short pronounced ( '|' )
# #### 2. Guruvu: Long pronounced ( 'U' )

# %%
lg_data= lg.generate()
print( lg_data )
# Out:
# [('తొం', 'U'), ('డ', '|'), ('ము', '|'), ('నే', 'U'), ('క', '|'), ('దం', 'U'), ('త', '|'), ('ము', '|'), ('ను', '|'), ('తో', 'U'), ('ర', '|'), ('పు', '|'), ('బొ', 'U'), ('జ్జ', '|'), ('యు', '|'), ('వా', 'U'), ('మ', '|'), ('హ', 'U'), ('స్త', '|'), ('మున్', 'U'), ('మెం', 'U'), ('డు', '|'), ('గ', '|'), ('మ్రో', 'U'), ('యు', '|'), ('గ', 'U'), ('జ్జె', '|'), ('లు', '|'), ('ను', '|'), ('మె', 'U'), ('ల్ల', '|'), ('ని', '|'), ('చూ', 'U'), ('పు', '|'), ('లు', '|'), ('మం', 'U'), ('ద', '|'), ('హా', 'U'), ('స', '|'), ('మున్', 'U'), ('కొం', 'U'), ('డొ', '|'), ('క', '|'), ('గు', 'U'), ('జ్జు', '|'), ('రూ', 'U'), ('ప', '|'), ('ము', '|'), ('న', '|'), ('కో', 'U'), ('రి', '|'), ('న', '|'), ('వి', 'U'), ('ద్య', '|'), ('ల', '|'), ('కె', 'U'), ('ల్ల', '|'), ('నొ', 'U'), ('జ్జ', '|'), ('వై', 'U'), ('యుం', 'U'), ('డె', '|'), ('డి', '|'), ('పా', 'U'), ('ర్వ', '|'), ('తీ', 'U'), ('త', '|'), ('న', '|'), ('య', '|'), ('యో', 'U'), ('యి', '|'), ('గ', '|'), ('ణా', 'U'), ('ధి', '|'), ('ప', '|'), ('నీ', 'U'), ('కు', '|'), ('మ్రొ', 'U'), ('క్కె', '|'), ('దన్', 'U')]

# %% [markdown]
# ### Scoring

# %% [markdown]
# - n_paadalu: No.of lines
# - gana_kramam: Syllabic sequence
# - yati_sthanam: Caesura Position
# - N Aksharalu: N Character Tokens
# - Prasa: Alliteration

# %%
score= check_padyam( 
                        lg_data= lg_data ,
                        type= "vutpalamaala",
                        return_micro_score= True, 
                        verbose= False
                    )
print( score )
# Out:
# {'chandassu_score': 1.0, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 1.0, 'yati_sthanam': 1.0, 'n_aksharalu': 1.0, 'prasa': 1.0}}

# %%
score= check_padyam( 
                        lg_data= lg_data ,
                        type= "champakamaala",
                        return_micro_score= True, 
                        verbose= False
                    )
print( score )
# Out:
# {'chandassu_score': 0.5261904761904762, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.17857142857142858, 'yati_sthanam': 0.0, 'n_aksharalu': 0.9523809523809523, 'prasa': 0.5}}

# %%
score= check_padyam( 
                        lg_data= lg_data ,
                        type= "kandamu",
                        return_micro_score= True, 
                        verbose= False
                    )
print( score )
# Out:
# {'chandassu_score': 0.46875, 'micro_score': {'n_paadalu': 1.0, 'gana_kramam': 0.625, 'yati_sthanam': 0.0, 'prasa': 0.25}}

# %% [markdown]
# ### END
# ---
