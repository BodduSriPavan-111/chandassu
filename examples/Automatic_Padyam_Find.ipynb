# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# import pandas as pd

# from chandassu.telugu.laghuvu_guruvu import LaghuvuGuruvu
from chandassu.telugu.padya_bhedam import find_padyam

# %%
padyam= """శ్రీరఘురామ చారుతులసీదళదామ శమక్షమాది శృం
గారగుణాభిరామ త్రిజగన్నుతశౌర్యరమాలలామ దు
ర్వార కబంధరాక్షసవిరామ జగజ్జనకల్మషార్ణవో
త్తారకనామ భద్రగిరి దాశరథీ! కరుణాపయోనిధీ"""

find_padyam(data= padyam)
# Out:
# [0.9928571428571429, 'vutpalamaala']

# %%
result= find_padyam(data= padyam)
result
# Out:
# [0.9928571428571429, 'vutpalamaala']

# %%
result= find_padyam(
    
                    data= padyam, 
                    weights= {'n_paadalu': 1.0, 'gana_kramam': 1.0, 'yati_sthanam': 0.5, 'n_aksharalu': 0.5, 'prasa': 0.5}
                )
result
# Out:
# [0.9897959183673469, 'vutpalamaala']

# %%
result= find_padyam(
    
                    data= padyam, 
                    weights= {'n_paadalu': 1.0, 'gana_kramam': 1.0, 'yati_sthanam': 0.5, 'n_aksharalu': 0.5, 'prasa': 0.5},
                    return_micro_score= True
                )
result
# Out:
# [0.9897959183673469,
#  {'n_paadalu': 1.0,
#   'gana_kramam': 0.9642857142857143,
#   'yati_sthanam': 1.0,
#   'n_aksharalu': 1.0,
#   'prasa': 1.0},
#  'vutpalamaala']

# %%
result= find_padyam(data= padyam, return_micro_score= True)
result
# Out:
# [0.9928571428571429,
#  {'n_paadalu': 1.0,
#   'gana_kramam': 0.9642857142857143,
#   'yati_sthanam': 1.0,
#   'n_aksharalu': 1.0,
#   'prasa': 1.0},
#  'vutpalamaala']

# %%
result= find_padyam(data= padyam, return_micro_score= True, return_type_wise_score= True)
result
# Out:
# [[0.9928571428571429,
#   {'n_paadalu': 1.0,
#    'gana_kramam': 0.9642857142857143,
#    'yati_sthanam': 1.0,
#    'n_aksharalu': 1.0,
#    'prasa': 1.0},
#   'vutpalamaala'],
#  [0.6357142857142858,
#   {'n_paadalu': 1.0,
#    'gana_kramam': 0.17857142857142858,
#    'yati_sthanam': 0.0,
#    'n_aksharalu': 1.0,
#    'prasa': 1.0},
#   'mattebhamu'],
#  [0.5666666666666667,
#   {'n_paadalu': 1.0, 'gana_kramam': 0.45, 'yati_sthanam': 0.25},
#   'aataveladi'],
#  [0.5333333333333333,
#   {'n_paadalu': 1.0, 'gana_kramam': 0.35, 'yati_sthanam': 0.25},
#   'teytageethi'],
#  [0.53125,
#   {'n_paadalu': 1.0, 'gana_kramam': 0.625, 'yati_sthanam': 0.0, 'prasa': 0.5},
#   'kandamu'],
#  [0.5261904761904762,
#   {'n_paadalu': 1.0,
#    'gana_kramam': 0.17857142857142858,
#    'yati_sthanam': 0.25,
#    'n_aksharalu': 0.9523809523809523,
#    'prasa': 0.25},
#   'champakamaala'],
#  [0.5251879699248121,
#   {'n_paadalu': 1.0,
#    'gana_kramam': 0.17857142857142858,
#    'yati_sthanam': 0.25,
#    'n_aksharalu': 0.9473684210526315,
#    'prasa': 0.25},
#   'saardulamu'],
#  [0.375,
#   {'n_paadalu': 0.75, 'gana_kramam': 0.375, 'yati_sthanam': 0.0},
#   'seesamu']]

# %%
result= find_padyam(data= padyam, verbose= True)
# Out:
# Type:  kandamu
# Bhedam:  <class 'chandassu.telugu.padyam_config.Jaathi'>
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', '|')
# Ganam :  ('U', '|', '|')
# [[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ']
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', '|')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U', '|')
# Key Not Found:  ('U', '|', 'U', '|')
# Exception:  ('U', '|', 'U', '|')
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# [[('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'స']
# 0 10 80 [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U'), ('రు', '|')], 'UnMatched'], [[('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'స']]
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# [[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'స']
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'స']
# {'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', 'U', '|')
# [[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'జ']
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', 'U')
# [[('శృం', 'U'), ('గా', 'U')], 'గా']
# {'గా': ('U', 'U'), 'స': ('|', '|', 'U')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# [[('ర', '|'), ('గు', '|'), ('ణా', 'U')], 'స']
# 1 24 80 [[[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'స'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'స'], [[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'జ'], [[('శృం', 'U'), ('గా', 'U')], 'గా'], [[('ర', '|'), ('గు', '|'), ('ణా', 'U')], 'స']]
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# [[('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'జ']
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# 2 35 80 [[[('భి', '|'), ('రా', 'U'), ('మ', '|'), ('త్రి', '|')], 'UnMatched'], [[('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'జ'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched']]
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', '|')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U', '|')
# Key Not Found:  ('U', '|', 'U', '|')
# Exception:  ('U', '|', 'U', '|')
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', 'U')
# [[('దు', 'U'), ('ర్వా', 'U')], 'గా']
# {'జ': ('|', 'U', '|'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# {'గా': ('U', 'U'), 'భ': ('U', '|', '|'), 'స': ('|', '|', 'U'), 'నల': ('|', '|', '|', '|')}
# Ganam :  ('U', '|')
# Ganam :  ('U', '|', '|')
# [[('రా', 'U'), ('క్ష', '|'), ('స', '|')], 'భ']
# {'గా': ('U', 'U'), 'స': ('|', '|', 'U')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# 3 51 80 [[[('మా', 'U'), ('ల', '|'), ('లా', 'U'), ('మ', '|')], 'UnMatched'], [[('దు', 'U'), ('ర్వా', 'U')], 'గా'], [[('ర', '|'), ('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|'), ('స', '|')], 'భ'], [[('వి', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched']]
# Paadalu to follow Yati:  (2, 4)
# No.of paadalu to follow Yati:  2
# Updated paadamwise_ganam_data:
# [[[[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'స'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'స'], [[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'జ'], [[('శృం', 'U'), ('గా', 'U')], 'గా'], [[('ర', '|'), ('గు', '|'), ('ణా', 'U')], 'స']], [[[('మా', 'U'), ('ల', '|'), ('లా', 'U'), ('మ', '|')], 'UnMatched'], [[('దు', 'U'), ('ర్వా', 'U')], 'గా'], [[('ర', '|'), ('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|'), ('స', '|')], 'భ'], [[('వి', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched']]]
# [[[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'స'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'స'], [[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'జ'], [[('శృం', 'U'), ('గా', 'U')], 'గా'], [[('ర', '|'), ('గు', '|'), ('ణా', 'U')], 'స']]
# First aksharam (letter):  ద
# Yati sthana aksharam (letter):  శృ
# Chihna yati mismatch occurred between ' ' in 'ద'  and 'ృ' in 'శృ'
# Generic Yati:  False
# ['ద', 'ళ', 'దా'] ('శృం', 'U')
# [[[('మా', 'U'), ('ల', '|'), ('లా', 'U'), ('మ', '|')], 'UnMatched'], [[('దు', 'U'), ('ర్వా', 'U')], 'గా'], [[('ర', '|'), ('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|'), ('స', '|')], 'భ'], [[('వి', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched']]
# First aksharam (letter):  మా
# Yati sthana aksharam (letter):  రా
# Yati mismatch occurred between 'మ' in 'మా' and 'రా'
# Generic Yati:  False
# ['మా', 'ల', 'లా', 'మ'] ('రా', 'U')
# Paadam Count:  4
# Ganam Kramam Score:  10
# Paadam-wise Yati:  [False, False]
# true_n_paadalu parameter found in config 4
# ర
# ళ
# ర
# ల
# Frequency of second aksharam (letter):  {'ర': 2, 'ళ': 1, 'ల': 1}
# Prasa Mismatch Occurred :  {'ర': 2, 'ళ': 1, 'ల': 1}
#
# Total Weighted Sum     :  2.125
# Total weights          :  4.0
# Type:  aataveladi
# Bhedam:  <class 'chandassu.telugu.padyam_config.VupaJaathi'>
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('శ్రీ', 'U'), ('ర', '|')], 'హ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('చా', 'U'), ('రు', '|')], 'హ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# [[('తు', '|'), ('ల', '|'), ('సీ', 'U'), ('ద', '|')], 'సల']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# 0 15 80 [[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched'], [[('చా', 'U'), ('రు', '|')], 'హ'], [[('తు', '|'), ('ల', '|'), ('సీ', 'U'), ('ద', '|')], 'సల'], [[('ళ', '|'), ('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('మ', 'U'), ('క్ష', '|')], 'హ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('మా', 'U'), ('ది', '|')], 'హ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', 'U')
# Ganam :  ('U', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('రా', 'U'), ('మ', '|')], 'హ']
# 1 27 80 [[[('మ', 'U'), ('క్ష', '|')], 'హ'], [[('మా', 'U'), ('ది', '|')], 'హ'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', '|')
# [[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ']
# 2 43 80 [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('న్ను', '|'), ('త', '|'), ('శౌ', 'U')], 'UnMatched'], [[('ర్య', '|'), ('ర', '|'), ('మా', 'U')], 'UnMatched'], [[('ల', '|'), ('లా', 'U'), ('మ', '|'), ('దు', 'U')], 'UnMatched'], [[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('బం', 'U'), ('ధ', '|')], 'హ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('రా', 'U'), ('క్ష', '|')], 'హ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# 3 56 80 [[[('బం', 'U'), ('ధ', '|')], 'హ'], [[('రా', 'U'), ('క్ష', '|')], 'హ'], [[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']]
# Paadalu to follow Yati:  (1, 2, 3, 4)
# No.of paadalu to follow Yati:  4
# Updated paadamwise_ganam_data:
# [[[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched'], [[('చా', 'U'), ('రు', '|')], 'హ'], [[('తు', '|'), ('ల', '|'), ('సీ', 'U'), ('ద', '|')], 'సల'], [[('ళ', '|'), ('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched']], [[[('మ', 'U'), ('క్ష', '|')], 'హ'], [[('మా', 'U'), ('ది', '|')], 'హ'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']], [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('న్ను', '|'), ('త', '|'), ('శౌ', 'U')], 'UnMatched'], [[('ర్య', '|'), ('ర', '|'), ('మా', 'U')], 'UnMatched'], [[('ల', '|'), ('లా', 'U'), ('మ', '|'), ('దు', 'U')], 'UnMatched'], [[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ']], [[[('బం', 'U'), ('ధ', '|')], 'హ'], [[('రా', 'U'), ('క్ష', '|')], 'హ'], [[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']]]
# [[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|')], 'UnMatched'], [[('చా', 'U'), ('రు', '|')], 'హ'], [[('తు', '|'), ('ల', '|'), ('సీ', 'U'), ('ద', '|')], 'సల'], [[('ళ', '|'), ('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  తు
# Chihna yati mismatch occurred between 'ీ' in 'శ్రీ'  and 'ు' in 'తు'
# First Akshara Chihnam in Prasa Yati Mis-matched
# First Akshara Chihnam:  ీ
# Prasa Yathi Akshara Chihnam:  ు
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('మ', 'U'), ('క్ష', '|')], 'హ'], [[('మా', 'U'), ('ది', '|')], 'హ'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']]
# First aksharam (letter):  మ
# Yati sthana aksharam (letter):  గు
# Chihna yati mismatch occurred between ' ' in 'మ'  and 'ు' in 'గు'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  క్ష === ణ
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('న్ను', '|'), ('త', '|'), ('శౌ', 'U')], 'UnMatched'], [[('ర్య', '|'), ('ర', '|'), ('మా', 'U')], 'UnMatched'], [[('ల', '|'), ('లా', 'U'), ('మ', '|'), ('దు', 'U')], 'UnMatched'], [[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ']]
# First aksharam (letter):  త్రి
# Yati sthana aksharam (letter):  ల
# Chihna yati mismatch occurred between 'ి' in 'త్రి'  and ' ' in 'ల'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  జ === ల
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('బం', 'U'), ('ధ', '|')], 'హ'], [[('రా', 'U'), ('క్ష', '|')], 'హ'], [[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']]
# First aksharam (letter):  బ
# Yati sthana aksharam (letter):  మ
# బ ['ప', 'ఫ', 'బ', 'భ', 'మ'] మ
# Yati Matched !
# Generic Yati Matched
# Paadam Count:  4
# Ganam Kramam Score:  9
# Paadam-wise Yati:  [False, False, False, True]
# true_n_paadalu parameter found in config 4
# Total Weighted Sum     :  1.7
# Total weights          :  3.0
# Type:  teytageethi
# Bhedam:  <class 'chandassu.telugu.padyam_config.VupaJaathi'>
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('శ్రీ', 'U'), ('ర', '|')], 'హ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|', 'U')
# Ganam :  ('|', '|', '|', 'U')
# [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# 0 16 80 [[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'UnMatched'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'UnMatched']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', 'U', '|')
# Ganam :  ('U', 'U', '|')
# Ganam :  ('U', 'U', '|')
# [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'త']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', '|')
# [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('గ', 'U'), ('న్ను', '|')], 'హ']
# 1 31 80 [[[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'UnMatched'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'త'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|')], 'హ']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('రా', 'U'), ('క్ష', '|')], 'హ']
# 2 47 80 [[[('త', '|'), ('శౌ', 'U'), ('ర్య', '|')], 'UnMatched'], [[('ర', '|'), ('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched'], [[('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|')], 'హ']]
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# [[('మ', '|'), ('జ', '|'), ('గ', 'U'), ('జ్జ', '|')], 'సల']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# 3 64 80 [[[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U'), ('జ్జ', '|')], 'సల'], [[('న', '|'), ('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U'), ('త్తా', 'U')], 'UnMatched'], [[('ర', '|'), ('క', '|'), ('నా', 'U')], 'UnMatched']]
# Paadalu to follow Yati:  (1, 2, 3, 4)
# No.of paadalu to follow Yati:  4
# Updated paadamwise_ganam_data:
# [[[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'UnMatched'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'UnMatched']], [[[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'UnMatched'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'త'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|')], 'హ']], [[[('త', '|'), ('శౌ', 'U'), ('ర్య', '|')], 'UnMatched'], [[('ర', '|'), ('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched'], [[('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|')], 'హ']], [[[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U'), ('జ్జ', '|')], 'సల'], [[('న', '|'), ('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U'), ('త్తా', 'U')], 'UnMatched'], [[('ర', '|'), ('క', '|'), ('నా', 'U')], 'UnMatched']]]
# [[[('శ్రీ', 'U'), ('ర', '|')], 'హ'], [[('ఘు', '|'), ('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U')], 'UnMatched'], [[('మ', '|'), ('శ', '|'), ('మ', 'U')], 'UnMatched']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  ద
# Chihna yati mismatch occurred between 'ీ' in 'శ్రీ'  and ' ' in 'ద'
# First Akshara Chihnam in Prasa Yati Mis-matched
# First Akshara Chihnam:  ీ
# Prasa Yathi Akshara Chihnam:
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('క్ష', '|'), ('మా', 'U'), ('ది', '|')], 'UnMatched'], [[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'త'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|')], 'హ']]
# First aksharam (letter):  క్ష
# Yati sthana aksharam (letter):  మ
# Yati mismatch occurred between 'ష' in 'క్ష' and 'మ'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  మ === త్ర
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('త', '|'), ('శౌ', 'U'), ('ర్య', '|')], 'UnMatched'], [[('ర', '|'), ('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched'], [[('క', '|'), ('బం', 'U'), ('ధ', '|')], 'UnMatched'], [[('రా', 'U'), ('క్ష', '|')], 'హ']]
# First aksharam (letter):  త
# Yati sthana aksharam (letter):  క
# Yati mismatch occurred between 'త' in 'త' and 'క'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  శ === బ
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('స', '|'), ('వి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('జ', '|'), ('గ', 'U'), ('జ్జ', '|')], 'సల'], [[('న', '|'), ('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U'), ('త్తా', 'U')], 'UnMatched'], [[('ర', '|'), ('క', '|'), ('నా', 'U')], 'UnMatched']]
# First aksharam (letter):  స
# Yati sthana aksharam (letter):  ర్ణ
# Yati mismatch occurred between 'స' in 'స' and 'ర్ణ'
# Both Yati Sthanam aksharam: Hraswa
# Both Yati Sthanam chihnam matched
# Prasa Yati Matched
# Paadam Count:  4
# Ganam Kramam Score:  7
# Paadam-wise Yati:  [False, False, False, True]
# true_n_paadalu parameter found in config 4
# Total Weighted Sum     :  1.6
# Total weights          :  3.0
# Type:  seesamu
# Bhedam:  <class 'chandassu.telugu.padyam_config.VupaJaathi'>
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', '|')
# [[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|', 'U')
# Ganam :  ('|', '|', '|', 'U')
# [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# [[('ద', '|'), ('ళ', '|'), ('దా', 'U'), ('మ', '|')], 'సల']
# 0 14 80 [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U'), ('మ', '|')], 'సల']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U', '|')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('U', '|')
# [[('రా', 'U'), ('మ', '|')], 'హ']
# 1 27 80 [[[('శ', '|'), ('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# [[('త్రి', '|'), ('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'సల']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# Ganam :  ('|', 'U', '|', '|')
# Key Not Found:  ('|', 'U', '|', '|')
# Exception:  ('|', 'U', '|', '|')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', 'U')
# Ganam :  ('U', '|', 'U')
# [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# Ganam :  ('|', 'U', 'U', '|')
# Key Not Found:  ('|', 'U', 'U', '|')
# Exception:  ('|', 'U', 'U', '|')
# 2 42 80 [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'సల'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|', 'U')
# Ganam :  ('|', '|', '|', 'U')
# [[('క్ష', '|'), ('స', '|'), ('వి', '|'), ('రా', 'U')], 'నగ']
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', '|')
# Ganam :  ('|', '|', 'U')
# 3 56 80 [[[('క', '|'), ('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|'), ('రా', 'U')], 'నగ'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', '|')
# [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('U', '|', '|')
# [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|')
# Ganam :  ('|', '|', '|', 'U')
# Ganam :  ('|', '|', '|', 'U')
# [[('ద్ర', '|'), ('గి', '|'), ('రి', '|'), ('దా', 'U')], 'నగ']
# 4 70 80 [[[('ల్మ', '|'), ('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')], 'UnMatched'], [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|'), ('దా', 'U')], 'నగ']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# Ganam :  ('|', '|', 'U', '|')
# [[('శ', '|'), ('ర', '|'), ('థీ', 'U'), ('క', '|')], 'సల']
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# Ganam :  ('|', 'U', '|', 'U')
# Key Not Found:  ('|', 'U', '|', 'U')
# Exception:  ('|', 'U', '|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ('|', 'U')
# Ganam :  ('|', 'U')
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# 5 84 80 [[[('శ', '|'), ('ర', '|'), ('థీ', 'U'), ('క', '|')], 'సల'], [[('రు', '|'), ('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'UnMatched'], [[], 'UnMatched']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# 6 100 80 [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']]
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'భ': ('U', '|', '|'), 'ర': ('U', '|', 'U'), 'త': ('U', 'U', '|'), 'నల': ('|', '|', '|', '|'), 'నగ': ('|', '|', '|', 'U'), 'సల': ('|', '|', 'U', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# {'హ': ('U', '|'), 'న': ('|', '|', '|')}
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# Ganam :  ()
# Key Not Found:  ()
# Exception:  ()
# 7 114 80 [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']]
# Paadalu to follow Yati:  (1, 2, 3, 4, 5, 6, 7, 8)
# No.of paadalu to follow Yati:  8
# Updated paadamwise_ganam_data:
# [[[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U'), ('మ', '|')], 'సల']], [[[('శ', '|'), ('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']], [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'సల'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched']], [[[('క', '|'), ('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|'), ('రా', 'U')], 'నగ'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']], [[[('ల్మ', '|'), ('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')], 'UnMatched'], [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|'), ('దా', 'U')], 'నగ']], [[[('శ', '|'), ('ర', '|'), ('థీ', 'U'), ('క', '|')], 'సల'], [[('రు', '|'), ('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'UnMatched'], [[], 'UnMatched']], [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']], [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']]]
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|'), ('సీ', 'U')], 'నగ'], [[('ద', '|'), ('ళ', '|'), ('దా', 'U'), ('మ', '|')], 'సల']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  రు
# Chihna yati mismatch occurred between 'ీ' in 'శ్రీ'  and 'ు' in 'రు'
# First Akshara Chihnam in Prasa Yati Mis-matched
# First Akshara Chihnam:  ీ
# Prasa Yathi Akshara Chihnam:  ు
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('శ', '|'), ('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|')], 'హ']]
# First aksharam (letter):  శ
# Yati sthana aksharam (letter):  గు
# Chihna yati mismatch occurred between ' ' in 'శ'  and 'ు' in 'గు'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  మ === ణ
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('త్రి', '|'), ('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'సల'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U'), ('ర', '|')], 'UnMatched']]
# First aksharam (letter):  త్రి
# Yati sthana aksharam (letter):  మా
# Chihna yati mismatch occurred between 'ి' in 'త్రి'  and 'ా' in 'మా'
# First Akshara Chihnam in Prasa Yati Mis-matched
# First Akshara Chihnam:  ి
# Prasa Yathi Akshara Chihnam:  ా
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('క', '|'), ('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|'), ('రా', 'U')], 'నగ'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched']]
# First aksharam (letter):  క
# Yati sthana aksharam (letter):  మ
# Yati mismatch occurred between 'క' in 'క' and 'మ'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  బ === జ
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('ల్మ', '|'), ('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')], 'UnMatched'], [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|'), ('దా', 'U')], 'నగ']]
# First aksharam (letter):  ల్మ
# Yati sthana aksharam (letter):  నా
# Yati mismatch occurred between 'మ' in 'ల్మ' and 'నా'
# First Akshara Chihnam in Prasa Yati Mis-matched
# First Akshara Chihnam:
# Prasa Yathi Akshara Chihnam:  ా
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[('శ', '|'), ('ర', '|'), ('థీ', 'U'), ('క', '|')], 'సల'], [[('రు', '|'), ('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'UnMatched'], [[], 'UnMatched']]
# First aksharam (letter):  శ
# Yati sthana aksharam (letter):  ని
# Chihna yati mismatch occurred between ' ' in 'శ'  and 'ి' in 'ని'
# Both Yati Sthanam aksharam: Hraswa
# Second Letter Mismatched:  ర === ధ
# Prasa Yati Mis-matched
# Both Yati and PrasaYati mis-matched
# [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']]
# No paadam found
# [[[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched'], [[], 'UnMatched']]
# No paadam found
# Paadam Count:  6
# Ganam Kramam Score:  12
# Paadam-wise Yati:  [False, False, False, False, False, False, False, False]
# Total Weighted Sum     :  1.125
# Total weights          :  3.0
# Type:  vutpalamaala
# Bhedam:  <class 'chandassu.telugu.padyam_config.Vruttamu'>
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర']
# {'న': ('|', '|', '|')}
# Ganam :  ('|', '|', '|')
# [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'న']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'భ']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'ర']
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ది', '|'), ('శృం', 'U')], 'వ']
# 0 20 80 [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'న'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'భ'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'భ'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'ర'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'ర']
# {'న': ('|', '|', '|')}
# Ganam :  ('|', '|', '|')
# [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'భ']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర']
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('మ', '|'), ('దు', 'U')], 'వ']
# 1 40 80 [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'భ'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'ర'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'భ'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'భ'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U')], 'వ']]
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'ర']
# {'న': ('|', '|', '|')}
# Ganam :  ('|', '|', '|')
# [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'న']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'భ']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'ర']
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ర్ణ', '|'), ('వో', 'U')], 'వ']
# 2 60 80 [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'ర'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'న'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'భ'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'భ'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'ర'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']]
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', '|')
# {'న': ('|', '|', '|')}
# Ganam :  ('|', '|', '|')
# [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'న']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'భ']
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('U', '|', 'U')
# [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'ర']
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ని', '|'), ('ధీ', 'U')], 'వ']
# 3 80 80 [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'UnMatched'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'న'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'భ'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'భ'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'ర'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]
# Paadam wise split completed
# Paadalu to follow Yati:  (1, 2, 3, 4)
# No.of paadalu to follow Yati:  4
# Updated paadamwise_ganam_data:
# [[[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'న'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'భ'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'భ'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'ర'], [[('ది', '|'), ('శృం', 'U')], 'వ']], [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'భ'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'ర'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'భ'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'భ'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U')], 'వ']], [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'ర'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'న'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'భ'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'భ'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'ర'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']], [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'UnMatched'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'న'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'భ'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'భ'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'ర'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]]
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'న'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'భ'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'భ'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'ర'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  సీ
# శ ['చ', 'ఛ', 'జ', 'ఝ', 'శ', 'ష', 'స'] స
# Yati Matched !
# Generic Yati:  True
# ['శ్రీ', 'ర', 'ఘు'] ('సీ', 'U')
# [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'భ'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'ర'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'న'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'భ'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'భ'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'ర'], [[('మ', '|'), ('దు', 'U')], 'వ']]
# First aksharam (letter):  గా
# Yati sthana aksharam (letter):  గ
# గ ['క', 'ఖ', 'గ', 'ఘ'] గ
# Yati Matched !
# Generic Yati:  True
# ['గా', 'ర', 'గు'] ('గ', 'U')
# [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'ర'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'న'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'భ'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'భ'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'ర'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']]
# First aksharam (letter):  ర్వా
# Yati sthana aksharam (letter):  రా
# ర ['ఋ', 'ర', 'ి', 'ీ', 'ె', 'ే'] ర
# Yati Matched !
# Generic Yati:  True
# ['ర్వా', 'ర', 'క'] ('రా', 'U')
# [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'భ'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'UnMatched'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'న'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'భ'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'భ'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'ర'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]
# First aksharam (letter):  త్తా
# Yati sthana aksharam (letter):  దా
# త ['త', 'థ', 'ద', 'ధ'] ద
# Yati Matched !
# Generic Yati:  True
# ['త్తా', 'ర', 'క'] ('దా', 'U')
# Paadam Count:  4
# Ganam Kramam Score:  27
# Paadam-wise Yati:  [True, True, True, True]
# true_n_paadalu parameter found in config 4
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'భ'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'ర'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'న'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'భ'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'భ'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'ర'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# [('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')] 3
# [('రా', 'U'), ('మ', '|'), ('చా', 'U')] 3
# [('రు', '|'), ('తు', '|'), ('ల', '|')] 3
# [('సీ', 'U'), ('ద', '|'), ('ళ', '|')] 3
# [('దా', 'U'), ('మ', '|'), ('శ', '|')] 3
# [('మ', 'U'), ('క్ష', '|'), ('మా', 'U')] 3
# [('ది', '|'), ('శృం', 'U')] 2
# ...
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|')], 'UnMatched']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  దా
# Chihna yati mismatch occurred between 'ీ' in 'శ్రీ'  and 'ా' in 'దా'
# Generic Yati:  False
# ['శ్రీ', 'ర', 'ఘు'] ('దా', 'U')
# [[[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('త్రి', '|')], 'UnMatched'], [[('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'UnMatched'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|')], 'UnMatched'], [[('ర', '|'), ('మా', 'U'), ('ల', '|')], 'UnMatched'], [[('లా', 'U')], 'గ']]
# First aksharam (letter):  శృ
# Yati sthana aksharam (letter):  త
# Chihna yati mismatch occurred between 'ృ' in 'శృ'  and ' ' in 'త'
# Generic Yati:  False
# ['శృం', 'గా', 'ర'] ('త', '|')
# [[[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U')], 'UnMatched'], [[('ర', '|'), ('క', '|'), ('బం', 'U')], 'స'], [[('ధ', '|'), ('రా', 'U'), ('క్ష', '|')], 'జ'], [[('స', '|'), ('వి', '|'), ('రా', 'U')], 'స'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched'], [[('ల్మ', '|')], 'UnMatched']]
# First aksharam (letter):  మ
# Yati sthana aksharam (letter):  మ
# మ ['ప', 'ఫ', 'బ', 'భ', 'మ'] మ
# Yati Matched !
# Generic Yati:  True
# ['మ', 'దు', 'ర్వా'] ('మ', '|')
# [[[('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')], 'UnMatched'], [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'UnMatched'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U')], 'గ']]
# First aksharam (letter):  షా
# Yati sthana aksharam (letter):  దా
# Yati mismatch occurred between 'ష' in 'షా' and 'దా'
# Generic Yati:  False
# ['షా', 'ర్ణ', 'వో'] ('దా', 'U')
# Paadam Count:  4
# Ganam Kramam Score:  5
# Paadam-wise Yati:  [False, False, True, False]
# true_n_paadalu parameter found in config 4
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|')], 'UnMatched']]
# [('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')] 3
# [('రా', 'U'), ('మ', '|'), ('చా', 'U')] 3
# [('రు', '|'), ('తు', '|'), ('ల', '|')] 3
# [('సీ', 'U'), ('ద', '|'), ('ళ', '|')] 3
# [('దా', 'U'), ('మ', '|'), ('శ', '|')] 3
# [('మ', 'U'), ('క్ష', '|'), ('మా', 'U')] 3
# [('ది', '|')] 1
# [[[('శృం', 'U'), ('గా', 'U'), ('ర', '|')], 'UnMatched'], [[('గు', '|'), ('ణా', 'U'), ('భి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('త్రి', '|')], 'UnMatched'], [[('జ', '|'), ('గ', 'U'), ('న్ను', '|')], 'UnMatched'], [[('త', '|'), ('శౌ', 'U'), ('ర్య', '|')], 'UnMatched'], [[('ర', '|'), ('మా', 'U'), ('ల', '|')], 'UnMatched'], [[('లా', 'U')], 'గ']]
# [('శృం', 'U'), ('గా', 'U'), ('ర', '|')] 3
# [('గు', '|'), ('ణా', 'U'), ('భి', '|')] 3
# [('రా', 'U'), ('మ', '|'), ('త్రి', '|')] 3
# [('జ', '|'), ('గ', 'U'), ('న్ను', '|')] 3
# [('త', '|'), ('శౌ', 'U'), ('ర్య', '|')] 3
# [('ర', '|'), ('మా', 'U'), ('ల', '|')] 3
# [('లా', 'U')] 1
# [[[('మ', '|'), ('దు', 'U'), ('ర్వా', 'U')], 'UnMatched'], [[('ర', '|'), ('క', '|'), ('బం', 'U')], 'స'], [[('ధ', '|'), ('రా', 'U'), ('క్ష', '|')], 'జ'], [[('స', '|'), ('వి', '|'), ('రా', 'U')], 'స'], [[('మ', '|'), ('జ', '|'), ('గ', 'U')], 'UnMatched'], [[('జ్జ', '|'), ('న', '|'), ('క', 'U')], 'UnMatched'], [[('ల్మ', '|')], 'UnMatched']]
# [('మ', '|'), ('దు', 'U'), ('ర్వా', 'U')] 3
# [('ర', '|'), ('క', '|'), ('బం', 'U')] 3
# [('ధ', '|'), ('రా', 'U'), ('క్ష', '|')] 3
# [('స', '|'), ('వి', '|'), ('రా', 'U')] 3
# [('మ', '|'), ('జ', '|'), ('గ', 'U')] 3
# [('జ్జ', '|'), ('న', '|'), ('క', 'U')] 3
# [('ల్మ', '|')] 1
# [[[('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')], 'UnMatched'], [[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'UnMatched'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U')], 'గ']]
# [('షా', 'U'), ('ర్ణ', '|'), ('వో', 'U')] 3
# [('త్తా', 'U'), ('ర', '|'), ('క', '|')] 3
# [('నా', 'U'), ('మ', '|'), ('భ', '|')] 3
# [('ద్ర', '|'), ('గి', '|'), ('రి', '|')] 3
# [('దా', 'U'), ('శ', '|'), ('ర', '|')] 3
# [('థీ', 'U'), ('క', '|'), ('రు', '|')] 3
# [('ణా', 'U')] 1
# ర
# గ
# ద
# ర్ణ
# Frequency of second aksharam (letter):  {'ర': 1, 'గ': 1, 'ద': 1, 'ర్ణ': 1}
# Prasa Mismatch Occurred :  {'ర': 1, 'గ': 1, 'ద': 1, 'ర్ణ': 1}
#
# Total Weighted Sum     :  2.6259398496240602
# Total weights          :  5.0
# Type:  mattebhamu
# Bhedam:  <class 'chandassu.telugu.padyam_config.Vruttamu'>
# {'స': ('|', '|', 'U')}
# Ganam :  ('U', '|', '|')
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', 'U')
# {'ర': ('U', '|', 'U')}
# Ganam :  ('|', '|', '|')
# {'న': ('|', '|', '|')}
# Ganam :  ('U', '|', '|')
# {'మ': ('U', 'U', 'U')}
# Ganam :  ('U', '|', '|')
# {'య': ('|', 'U', 'U')}
# Ganam :  ('U', '|', 'U')
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ది', '|'), ('శృం', 'U')], 'వ']
# 0 20 80 [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# {'స': ('|', '|', 'U')}
# Ganam :  ('U', '|', '|')
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', 'U')
# {'ర': ('U', '|', 'U')}
# Ganam :  ('|', '|', '|')
# {'న': ('|', '|', '|')}
# Ganam :  ('U', '|', '|')
# {'మ': ('U', 'U', 'U')}
# Ganam :  ('U', '|', '|')
# {'య': ('|', 'U', 'U')}
# Ganam :  ('U', '|', 'U')
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('మ', '|'), ('దు', 'U')], 'వ']
# 1 40 80 [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'UnMatched'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'UnMatched'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U')], 'వ']]
# {'స': ('|', '|', 'U')}
# Ganam :  ('U', '|', '|')
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', 'U')
# {'ర': ('U', '|', 'U')}
# Ganam :  ('|', '|', '|')
# {'న': ('|', '|', '|')}
# Ganam :  ('U', '|', '|')
# {'మ': ('U', 'U', 'U')}
# Ganam :  ('U', '|', '|')
# {'య': ('|', 'U', 'U')}
# Ganam :  ('U', '|', 'U')
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ర్ణ', '|'), ('వో', 'U')], 'వ']
# 2 60 80 [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'UnMatched'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']]
# {'స': ('|', '|', 'U')}
# Ganam :  ('U', '|', '|')
# {'భ': ('U', '|', '|')}
# Ganam :  ('U', '|', '|')
# [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ']
# {'ర': ('U', '|', 'U')}
# Ganam :  ('|', '|', '|')
# {'న': ('|', '|', '|')}
# Ganam :  ('U', '|', '|')
# {'మ': ('U', 'U', 'U')}
# Ganam :  ('U', '|', '|')
# {'య': ('|', 'U', 'U')}
# Ganam :  ('U', '|', 'U')
# {'వ': ('|', 'U')}
# Ganam :  ('|', 'U')
# [[('ని', '|'), ('ధీ', 'U')], 'వ']
# 3 80 80 [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]
# Paadam wise split completed
# Paadalu to follow Yati:  (1, 2, 3, 4)
# No.of paadalu to follow Yati:  4
# Updated paadamwise_ganam_data:
# [[[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U')], 'వ']], [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'UnMatched'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'UnMatched'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U')], 'వ']], [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'UnMatched'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']], [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]]
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# First aksharam (letter):  శ్రీ
# Yati sthana aksharam (letter):  మ
# Chihna yati mismatch occurred between 'ీ' in 'శ్రీ'  and ' ' in 'మ'
# Generic Yati:  False
# ['శ్రీ', 'ర', 'ఘు'] ('మ', '|')
# [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'UnMatched'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'UnMatched'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U')], 'వ']]
# First aksharam (letter):  గా
# Yati sthana aksharam (letter):  ర్య
# Yati mismatch occurred between 'గ' in 'గా' and 'ర్య'
# Generic Yati:  False
# ['గా', 'ర', 'గు'] ('ర్య', '|')
# [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'UnMatched'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']]
# First aksharam (letter):  ర్వా
# Yati sthana aksharam (letter):  జ్జ
# Yati mismatch occurred between 'వ' in 'ర్వా' and 'జ్జ'
# Generic Yati:  False
# ['ర్వా', 'ర', 'క'] ('జ్జ', '|')
# [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]
# First aksharam (letter):  త్తా
# Yati sthana aksharam (letter):  క
# Yati mismatch occurred between 'త' in 'త్తా' and 'క'
# Generic Yati:  False
# ['త్తా', 'ర', 'క'] ('క', '|')
# Paadam Count:  4
# Ganam Kramam Score:  5
# Paadam-wise Yati:  [False, False, False, False]
# true_n_paadalu parameter found in config 4
# [[[('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('చా', 'U')], 'UnMatched'], [[('రు', '|'), ('తు', '|'), ('ల', '|')], 'UnMatched'], [[('సీ', 'U'), ('ద', '|'), ('ళ', '|')], 'UnMatched'], [[('దా', 'U'), ('మ', '|'), ('శ', '|')], 'UnMatched'], [[('మ', 'U'), ('క్ష', '|'), ('మా', 'U')], 'UnMatched'], [[('ది', '|'), ('శృం', 'U')], 'వ']]
# [('శ్రీ', 'U'), ('ర', '|'), ('ఘు', '|')] 3
# [('రా', 'U'), ('మ', '|'), ('చా', 'U')] 3
# [('రు', '|'), ('తు', '|'), ('ల', '|')] 3
# [('సీ', 'U'), ('ద', '|'), ('ళ', '|')] 3
# [('దా', 'U'), ('మ', '|'), ('శ', '|')] 3
# [('మ', 'U'), ('క్ష', '|'), ('మా', 'U')] 3
# [('ది', '|'), ('శృం', 'U')] 2
# [[[('గా', 'U'), ('ర', '|'), ('గు', '|')], 'UnMatched'], [[('ణా', 'U'), ('భి', '|'), ('రా', 'U')], 'UnMatched'], [[('మ', '|'), ('త్రి', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('న్ను', '|'), ('త', '|')], 'UnMatched'], [[('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')], 'UnMatched'], [[('మా', 'U'), ('ల', '|'), ('లా', 'U')], 'UnMatched'], [[('మ', '|'), ('దు', 'U')], 'వ']]
# [('గా', 'U'), ('ర', '|'), ('గు', '|')] 3
# [('ణా', 'U'), ('భి', '|'), ('రా', 'U')] 3
# [('మ', '|'), ('త్రి', '|'), ('జ', '|')] 3
# [('గ', 'U'), ('న్ను', '|'), ('త', '|')] 3
# [('శౌ', 'U'), ('ర్య', '|'), ('ర', '|')] 3
# [('మా', 'U'), ('ల', '|'), ('లా', 'U')] 3
# [('మ', '|'), ('దు', 'U')] 2
# [[[('ర్వా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('బం', 'U'), ('ధ', '|'), ('రా', 'U')], 'UnMatched'], [[('క్ష', '|'), ('స', '|'), ('వి', '|')], 'UnMatched'], [[('రా', 'U'), ('మ', '|'), ('జ', '|')], 'UnMatched'], [[('గ', 'U'), ('జ్జ', '|'), ('న', '|')], 'UnMatched'], [[('క', 'U'), ('ల్మ', '|'), ('షా', 'U')], 'UnMatched'], [[('ర్ణ', '|'), ('వో', 'U')], 'వ']]
# [('ర్వా', 'U'), ('ర', '|'), ('క', '|')] 3
# [('బం', 'U'), ('ధ', '|'), ('రా', 'U')] 3
# [('క్ష', '|'), ('స', '|'), ('వి', '|')] 3
# [('రా', 'U'), ('మ', '|'), ('జ', '|')] 3
# [('గ', 'U'), ('జ్జ', '|'), ('న', '|')] 3
# [('క', 'U'), ('ల్మ', '|'), ('షా', 'U')] 3
# [('ర్ణ', '|'), ('వో', 'U')] 2
# [[[('త్తా', 'U'), ('ర', '|'), ('క', '|')], 'UnMatched'], [[('నా', 'U'), ('మ', '|'), ('భ', '|')], 'భ'], [[('ద్ర', '|'), ('గి', '|'), ('రి', '|')], 'UnMatched'], [[('దా', 'U'), ('శ', '|'), ('ర', '|')], 'UnMatched'], [[('థీ', 'U'), ('క', '|'), ('రు', '|')], 'UnMatched'], [[('ణా', 'U'), ('ప', '|'), ('యో', 'U')], 'UnMatched'], [[('ని', '|'), ('ధీ', 'U')], 'వ']]
# [('త్తా', 'U'), ('ర', '|'), ('క', '|')] 3
# [('నా', 'U'), ('మ', '|'), ('భ', '|')] 3
# [('ద్ర', '|'), ('గి', '|'), ('రి', '|')] 3
# [('దా', 'U'), ('శ', '|'), ('ర', '|')] 3
# [('థీ', 'U'), ('క', '|'), ('రు', '|')] 3
# [('ణా', 'U'), ('ప', '|'), ('యో', 'U')] 3
# [('ని', '|'), ('ధీ', 'U')] 2
# ర
# ర
# ర
# ర
# Frequency of second aksharam (letter):  {'ర': 4}
# Prasa Matched Successfully !
#
# Total Weighted Sum     :  3.178571428571429
# Total weights          :  5.0

# %% [markdown]
# #### END
# ---
